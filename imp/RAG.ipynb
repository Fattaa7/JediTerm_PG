# %%
! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain cohere
# Out:
# Requirement already satisfied: langchain_community in c:\workset\c5_rag\venv\lib\site-packages (0.3.30)
# Requirement already satisfied: tiktoken in c:\workset\c5_rag\venv\lib\site-packages (0.11.0)
# Requirement already satisfied: langchain-openai in c:\workset\c5_rag\venv\lib\site-packages (0.3.33)
# Requirement already satisfied: langchainhub in c:\workset\c5_rag\venv\lib\site-packages (0.1.21)
# Requirement already satisfied: chromadb in c:\workset\c5_rag\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain in c:\workset\c5_rag\venv\lib\site-packages (0.3.27)
# Requirement already satisfied: cohere in c:\workset\c5_rag\venv\lib\site-packages (5.18.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (0.3.76)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (0.4.31)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in c:\workset\c5_rag\venv\lib\site-packages (from langchain_community) (2.3.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\workset\c5_rag\venv\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\workset\c5_rag\venv\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\workset\c5_rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\workset\c5_rag\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\workset\c5_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\workset\c5_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\workset\c5_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\workset\c5_rag\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\workset\c5_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\workset\c5_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\workset\c5_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\workset\c5_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\workset\c5_rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: certifi in c:\workset\c5_rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\workset\c5_rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\workset\c5_rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\workset\c5_rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\workset\c5_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\workset\c5_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\workset\c5_rag\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\workset\c5_rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\workset\c5_rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\workset\c5_rag\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\workset\c5_rag\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\workset\c5_rag\venv\lib\site-packages (from tiktoken) (2025.9.18)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in c:\workset\c5_rag\venv\lib\site-packages (from langchain-openai) (1.109.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\workset\c5_rag\venv\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\workset\c5_rag\venv\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\workset\c5_rag\venv\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\workset\c5_rag\venv\lib\site-packages (from langchainhub) (2.32.4.20250913)
# Requirement already satisfied: build>=1.0.3 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\workset\c5_rag\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\workset\c5_rag\venv\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\workset\c5_rag\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\workset\c5_rag\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\workset\c5_rag\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\workset\c5_rag\venv\lib\site-packages (from cohere) (1.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\workset\c5_rag\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.1)
# Requirement already satisfied: filelock in c:\workset\c5_rag\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\workset\c5_rag\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: pyproject_hooks in c:\workset\c5_rag\venv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\workset\c5_rag\venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\workset\c5_rag\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\workset\c5_rag\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\workset\c5_rag\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\workset\c5_rag\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\workset\c5_rag\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\workset\c5_rag\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\workset\c5_rag\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\workset\c5_rag\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\workset\c5_rag\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\workset\c5_rag\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\workset\c5_rag\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\workset\c5_rag\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\workset\c5_rag\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\workset\c5_rag\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\workset\c5_rag\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: sympy in c:\workset\c5_rag\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\workset\c5_rag\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\workset\c5_rag\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\workset\c5_rag\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\workset\c5_rag\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\workset\c5_rag\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\workset\c5_rag\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\workset\c5_rag\venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\workset\c5_rag\venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\workset\c5_rag\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in c:\workset\c5_rag\venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\workset\c5_rag\venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\workset\c5_rag\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\workset\c5_rag\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\workset\c5_rag\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\workset\c5_rag\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\workset\c5_rag\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\workset\c5_rag\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
from PyPDF2 import PdfReader, PdfWriter

# Input and output file paths
input_pdf = "c5.pdf"
output_pdf = "output.pdf"

# Pages are zero-based in PyPDF2 (so page 8 is index 7, page 740 is index 739)
skip_start = 7      # page 8
skip_end = 738      # page 739 (excludes 740)

reader = PdfReader(input_pdf)
writer = PdfWriter()

for i in range(len(reader.pages)):
    if not (skip_start <= i <= skip_end):
        writer.add_page(reader.pages[i])

with open(output_pdf, "wb") as f:
    writer.write(f)

print(f"Saved new PDF to {output_pdf}")
# Out:
# Saved new PDF to output.pdf

# %%
input_pdf = "old.pdf"
reader = PdfReader(input_pdf)

# --- Extract page 1 ---
page1_writer = PdfWriter()
page1_writer.add_page(reader.pages[0])  # page 1 = index 0
with open("Artemis_v6.1_PIP_Front_Connectors_IOs.pdf", "wb") as f:
    page1_writer.write(f)

# --- Extract pages 2–7 ---
cre_writer = PdfWriter()
for i in range(1, 7):  # pages 2–7 → indices 1 to 6
    cre_writer.add_page(reader.pages[i])
with open("CRE_arguments.pdf", "wb") as f:
    cre_writer.write(f)

# --- Main document (everything from page 8 onwards) ---
main_writer = PdfWriter()
for i in range(7, len(reader.pages)):  # start from page 8 (index 7)
    main_writer.add_page(reader.pages[i])

with open("output.pdf", "wb") as f:
    main_writer.write(f)

print("✅ Done:")
print(" - Artemis_v6.1_PIP_Front_Connectors_IOs.pdf (page 1)")
print(" - CRE_arguments.pdf (pages 2–7)")
print(" - output.pdf (pages 8 and onwards)")
# Out:
# ✅ Done:
#  - Artemis_v6.1_PIP_Front_Connectors_IOs.pdf (page 1)
#  - CRE_arguments.pdf (pages 2–7)
#  - output.pdf (pages 8 and onwards)

# %%
import os
import re
from PyPDF2 import PdfReader

input_pdf = "output.pdf"
output_dir = "pages"
os.makedirs(output_dir, exist_ok=True)

# Read all text from PDF
reader = PdfReader(input_pdf)
full_text = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        full_text += text + "\n"

# Split by --- Parsing:
chunks = full_text.split("--- Parsing:")

for chunk in chunks:
    chunk = chunk.strip()
    if not chunk:
        continue

    # Look for the start of the URL
    url_match = re.search(r"https://sites\.google\.com/a/valeo\.com/castle-project/(.*?)---", chunk, re.S)
    if not url_match:
        continue

    # Extract the filename part (strip spaces/newlines)
    filename_part = url_match.group(1).strip().replace(" ", "").replace("\n", "")
    filename = filename_part.replace("/", "_") + ".txt"
    filepath = os.path.join(output_dir, filename)

    # Content is everything after the URL + --- marker
    content_start = url_match.end()
    content = chunk[content_start:].strip()

    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

    print(f"Saved: {filepath}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 13
#      11 full_text = ""
#      12 for page in reader.pages:
# ---> 13     text = page.extract_text()
#      14     if text:
#      15         full_text += text + "\n"
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\generic\_data_structures.py:877, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     875     stream_bytes = BytesIO(stream_data_bytes)
#     876 self.forced_encoding = forced_encoding
# --> 877 self.__parse_content_stream(stream_bytes)
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\generic\_data_structures.py:943, in ContentStream.__parse_content_stream(self, stream)
#     941         peek = stream.read(1)
#     942 else:
# --> 943     operands.append(read_object(stream, None, self.forced_encoding))
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\generic\_data_structures.py:1077, in read_object(stream, pdf, forced_encoding)
#    1075         return IndirectObject.read_from_stream(stream, pdf)
#    1076     else:
# -> 1077         return NumberObject.read_from_stream(stream)
#    1078 else:
#    1079     stream.seek(-20, 1)
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\generic\_base.py:407, in NumberObject.read_from_stream(stream)
#     405 num = read_until_regex(stream, NumberObject.NumberPattern)
#     406 if num.find(b".") != -1:
# --> 407     return FloatObject(num)
#     408 return NumberObject(num)
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\generic\_base.py:330, in FloatObject.__new__(cls, value, context)
#     326 def __new__(
#     327     cls, value: Union[str, Any] = "0", context: Optional[Any] = None
#     328 ) -> "FloatObject":
#     329     try:
# --> 330         return decimal.Decimal.__new__(cls, str_(value), context)
#     331     except Exception:
#     332         # If this isn't a valid decimal (happens in malformed PDFs)
#     333         # fallback to 0
#     334         logger_warning(f"FloatObject ({value}) invalid; use 0.0 instead", __name__)
#
# File c:\workset\C5_RAG\venv\Lib\site-packages\PyPDF2\_utils.py:290, in str_(b)
#     285 @overload
#     286 def str_(b: bytes) -> str:
#     287     ...
# --> 290 def str_(b: Union[str, bytes]) -> str:
#     291     if isinstance(b, bytes):
#     292         return b.decode("latin-1")
#
# KeyboardInterrupt:

# %%
from PyPDF2 import PdfReader

pdf_files = ["Artemis_v6.1_PIP_Front_Connectors_IOs.pdf", "CRE_arguments.pdf"]

for pdf_file in pdf_files:
    reader = PdfReader(pdf_file)
    text = ""
    for page in reader.pages:
        page_text = page.extract_text()
        if page_text:
            text += page_text + "\n"

    txt_file = pdf_file.replace(".pdf", ".txt")
    with open(txt_file, "w", encoding="utf-8") as f:
        f.write(text.strip())

    print(f"✅ Saved: {txt_file}")
# Out:
# ✅ Saved: Artemis_v6.1_PIP_Front_Connectors_IOs.txt
# ✅ Saved: CRE_arguments.txt

# %%
import os

folder = "pages"

for filename in os.listdir(folder):
    if filename.endswith(".txt"):
        filepath = os.path.join(folder, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            content = f.read().strip()
            word_count = len(content.split())

        if word_count < 20:
            os.remove(filepath)
            print(f"🗑️ Deleted {filename} (only {word_count} words)")
        else:
            print(f"✅ Kept {filename} ({word_count} words)")
# Out:
# 🗑️ Deleted about-us.txt (only 2 words)
# ✅ Kept about-us_the-team.txt (313 words)
# 🗑️ Deleted additional-offerings.txt (only 8 words)
# 🗑️ Deleted additional-offerings_arxml-generation-porcshe-sv62.txt (only 6 words)
# 🗑️ Deleted additional-offerings_castle-lite_raspberry-pi-as-a-castle-pim.txt (only 6 words)
# 🗑️ Deleted additional-offerings_virtual-castle.txt (only 2 words)
# 🗑️ Deleted additional-offerings_virtual-castle_vpim-user-guide-castle-virtual-pim.txt (only 3 words)
# ✅ Kept Artemis_v6.1_PIP_Front_Connectors_IOs.txt (141 words)
# ✅ Kept CRE_arguments.txt (1432 words)
# 🗑️ Deleted general-topics.txt (only 3 words)
# 🗑️ Deleted general-topics_autosar.txt (only 1 words)
# ✅ Kept general-topics_autosar_autosar42containersecuredpdus.txt (740 words)
# 🗑️ Deleted general-topics_can.txt (only 1 words)
# 🗑️ Deleted general-topics_can_canbustimingsamplingandconfiguration.txt (only 13 words)
# ✅ Kept general-topics_castle-6-bip-ethernet-interface.txt (442 words)
# ✅ Kept general-topics_castle-programming-adaptor.txt (25 words)
# 🗑️ Deleted general-topics_ethernet.txt (only 1 words)
# 🗑️ Deleted general-topics_ethernet_ethernet-training.txt (only 2 words)
# ✅ Kept general-topics_ethernet_lwip-v6-neighbor-discovery.txt (230 words)
# 🗑️ Deleted general-topics_ethernet_newvaleositeaboutautomotiveethernet.txt (only 14 words)
# ✅ Kept general-topics_ethernet_simulate-nodes-from-arxml-in-canoe.txt (412 words)
# ✅ Kept general-topics_ethernet_tcp.txt (1149 words)
# ✅ Kept general-topics_ethernet_tcpsegmentation.txt (282 words)
# ✅ Kept general-topics_ethernet_tls-in-castle.txt (374 words)
# ✅ Kept general-topics_ethernet_understandmaclayer.txt (980 words)
# 🗑️ Deleted general-topics_flexray.txt (only 1 words)
# ✅ Kept general-topics_flexray_flexray-diag.txt (26 words)
# ✅ Kept general-topics_flexray_flexrayonoscilloscope.txt (157 words)
# 🗑️ Deleted general-topics_i2c.txt (only 1 words)
# ✅ Kept general-topics_i2c_i2c-bus-pullup-resistor-calculation.txt (724 words)
# ✅ Kept general-topics_mipi-csi-2.txt (1408 words)
# ✅ Kept general-topics_mipi-csi-2_mipi-protocols.txt (580 words)
# ✅ Kept general-topics_mipi-csi-2_mipi-protocols_mipi-csi-2-2-of-2.txt (2801 words)
# ✅ Kept general-topics_mipi-csi-2_mipi-protocols_mipi-csi-2.txt (3432 words)
# ✅ Kept general-topics_mipi-csi-2_mipi-protocols_mipi-csi2-part-1.txt (2042 words)
# ✅ Kept general-topics_mipi-csi-2_mipi-protocols_mipi-csi2-part-2.txt (1819 words)
# 🗑️ Deleted general-topics_usv-sensors.txt (only 2 words)
# 🗑️ Deleted general-topics_usv-sensors_simulateusvsensorsechoeswithonsemiqttool.txt (only 15 words)
# 🗑️ Deleted general-topics_video-formats.txt (only 2 words)
# ✅ Kept general-topics_video-formats_understandingyuvvideodataformats.txt (392 words)
# ✅ Kept hardware.txt (25 words)
# 🗑️ Deleted hardware_calibration.txt (only 13 words)
# ✅ Kept hardware_castle-5.txt (433 words)
# 🗑️ Deleted hardware_castle-5_basis.txt (only 17 words)
# ✅ Kept hardware_castle-5_basis_baseboardsoftreset.txt (1622 words)
# 🗑️ Deleted hardware_castle-5_basis_basis-5-0.txt (only 2 words)
# ✅ Kept hardware_castle-5_basis_basis-5-1.txt (33 words)
# ✅ Kept hardware_castle-5_basis_basis-5-2.txt (97 words)
# ✅ Kept hardware_castle-5_basis_basis-5-3.txt (41 words)
# 🗑️ Deleted hardware_castle-5_basis_bootloader.txt (only 8 words)
# ✅ Kept hardware_castle-5_basis_bootloader_bootloaderflasherscript.txt (131 words)
# ✅ Kept hardware_castle-5_basis_bootloader_castle5clockmodulebootfailure.txt (650 words)
# ✅ Kept hardware_castle-5_basis_calibration.txt (140 words)
# ✅ Kept hardware_castle-5_basis_calibration_calibration.txt (23 words)
# 🗑️ Deleted hardware_castle-5_basis_pim-front-panel.txt (only 3 words)
# ✅ Kept hardware_castle-5_basis_waveformgenerator.txt (266 words)
# ✅ Kept hardware_castle-5_bip.txt (123 words)
# ✅ Kept hardware_castle-5_bip_bip-4-6.txt (269 words)
# ✅ Kept hardware_castle-5_bip_bip-4-6_can-sw-single-line.txt (251 words)
# ✅ Kept hardware_castle-5_bip_bip-4-7.txt (292 words)
# 🗑️ Deleted hardware_castle-5_bp-backplane.txt (only 2 words)
# 🗑️ Deleted hardware_castle-5_bp-backplane_bp-5-4.txt (only 2 words)
# 🗑️ Deleted hardware_castle-5_bp-backplane_bp-5-5.txt (only 2 words)
# 🗑️ Deleted hardware_castle-5_bp-backplane_serial-debug.txt (only 2 words)
# ✅ Kept hardware_castle-5_bp-backplane_serial-debug_c5-debugging-backplane-rs232.txt (179 words)
# ✅ Kept hardware_castle-5_bp-backplane_serial-debug_c5rackserialportconnection.txt (151 words)
# ✅ Kept hardware_castle-5_embase-1.txt (69 words)
# 🗑️ Deleted hardware_castle-5_embase-1_embase-1-1.txt (only 2 words)
# 🗑️ Deleted hardware_castle-5_embase-1_embase-1-2.txt (only 2 words)
# 🗑️ Deleted hardware_castle-5_embase-1_embase.txt (only 2 words)
# ✅ Kept hardware_castle-5_versioning.txt (370 words)
# 🗑️ Deleted hardware_castle-6.txt (only 8 words)
# 🗑️ Deleted hardware_castle-6_base.txt (only 1 words)
# ✅ Kept hardware_castle-6_base_base-board-soft-reset-c6.txt (101 words)
# ✅ Kept hardware_castle-6_base_base-r06-x-as-pcie-card.txt (81 words)
# ✅ Kept hardware_castle-6_base_base-rc06-23.txt (93 words)
# ✅ Kept hardware_castle-6_base_base-rc06-24.txt (83 words)
# ✅ Kept hardware_castle-6_bip.txt (443 words)
# ✅ Kept hardware_castle-6_bip_hw-patches_bip-switch-jtag-header.txt (384 words)
# ✅ Kept hardware_castle-6_bip_hw-patches_mv-switch-port-9-10g-2-5g.txt (372 words)
# ✅ Kept hardware_castle-6_castle-6-dbs-daughter-boards.txt (108 words)
# 🗑️ Deleted hardware_castle-6_castle-usb-3-0-interface.txt (only 4 words)
# ✅ Kept hardware_castle-6_serial-debug.txt (40 words)
# ✅ Kept hardware_pip-product-interface-pcbs.txt (141 words)
# ✅ Kept hardware_pip-product-interface-pcbs_cdoe-contact-design-of-experiment.txt (333 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_dms.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_dms_pip---dms_isc_gen2.txt (404 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_env.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_env_pip---env-test---r5-0.txt (299 words)
# ✅ Kept hardware_pip-product-interface-pcbs_env_pip---env-test---r5-1.txt (1033 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_front-camera.txt (only 2 words)
# ✅ Kept hardware_pip-product-interface-pcbs_front-camera_frontcamera_pip_v2.txt (53 words)
# ✅ Kept hardware_pip-product-interface-pcbs_front-camera_frontcamera_pip_v3.txt (82 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_generic-service-line.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_hud.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_hud_pip---hud-psa-d3.txt (266 words)
# ✅ Kept hardware_pip-product-interface-pcbs_hud_pip---whud-audi-ppc.txt (409 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---env-test---r5-1.txt (only 13 words)
# ✅ Kept hardware_pip-product-interface-pcbs_pip---et.txt (109 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---hud-psa-d3.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---radar-6e5997_988.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---scala-2-1.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---upa-3-8.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---usv10-master-r05-0.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip---usv10-slave-r05-2.txt (only 13 words)
# ✅ Kept hardware_pip-product-interface-pcbs_pip---zfls.txt (281 words)
# ✅ Kept hardware_pip-product-interface-pcbs_pip---zfls_pip---sent-trq-audi-vw.txt (232 words)
# ✅ Kept hardware_pip-product-interface-pcbs_pip---zfls_pip---zfls---r01-1.txt (217 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip--rlt--r01-0.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip-tcu-daimler-artemis.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_pip-tcu-vw-conmod2.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_radar.txt (only 1 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_radar_pip---radar-6e5997_988.txt (only 9 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_rlt.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_rlt_pip--rlt--r01-0.txt (301 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_rlt_rlt-r6-2.txt (only 2 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_scala.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_scala_pip---scala-2-0.txt (172 words)
# ✅ Kept hardware_pip-product-interface-pcbs_scala_pip---scala-2-1.txt (224 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_svs.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_camerafaultboxes.txt (151 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_gm_ti.txt (52 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_pip---fus_geely_fs11.txt (1041 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_pip---upa_hkm_k3.txt (548 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_rcvv2-0.txt (164 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_rcvv2-0_two-hw-patches.txt (304 words)
# ✅ Kept hardware_pip-product-interface-pcbs_svs_rvcv1-0.txt (210 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_tcm-epip-rev-2-1.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_tcm-epip-rev-2-1e486.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_tcm.txt (only 1 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_tcm_TCM-EPIP-Rev-11.txt (only 15 words)
# ✅ Kept hardware_pip-product-interface-pcbs_tcm_tcm-epip-rev-2-1.txt (375 words)
# ✅ Kept hardware_pip-product-interface-pcbs_tcm_tcm-epip-rev-2.txt (209 words)
# ✅ Kept hardware_pip-product-interface-pcbs_tcm_tcm-eval-r01-0.txt (92 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_telematics.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_telematics_pip-tcu-daimler-artemis.txt (854 words)
# ✅ Kept hardware_pip-product-interface-pcbs_telematics_pip-tcu-vw-conmod2.txt (696 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_uls-upit-ak-sensor-test.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_ultrasonic.txt (only 1 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_ultrasonic_upa.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_upa_pip---upa-3-6.txt (724 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_upa_pip---upa-3-7.txt (304 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_upa_pip---upa-3-8.txt (884 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_upa_uls-upit-ak-sensor-test.txt (152 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10.txt (243 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-master-r01-0.txt (212 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-master-r05-0.txt (239 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-r01-0.txt (559 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-slave-r05-1.txt (663 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-slave-r05-2.txt (758 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip---usv10-slave-r05-issues-patches.txt (238 words)
# ✅ Kept hardware_pip-product-interface-pcbs_ultrasonic_usv10_usv10-2-wire-master-r05-0.txt (253 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_usv10-2-wire-master-r05-0.txt (only 13 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_vls.txt (only 1 words)
# ✅ Kept hardware_pip-product-interface-pcbs_vls_vls_pip_v1.txt (416 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_zonal-controller.txt (only 2 words)
# ✅ Kept hardware_pip-product-interface-pcbs_zonal-controller_zonal-pip-v000093_2.txt (1458 words)
# 🗑️ Deleted hardware_pip-product-interface-pcbs_zonal-pip-v000093_2.txt (only 13 words)
# ✅ Kept hardware_racks.txt (867 words)
# ✅ Kept hardware_third-party-hardware.txt (61 words)
# ✅ Kept hardware_third-party-hardware_keysight-data-acquisition-switch-unit-34970a.txt (59 words)
# ✅ Kept hardware_third-party-hardware_keysight-io-libraries-suite.txt (55 words)
# ✅ Kept hardware_third-party-hardware_keysight-rf-sg-n9310a.txt (28 words)
# ✅ Kept hardware_third-party-hardware_keysight-wg-33511b.txt (20 words)
# ✅ Kept hardware_third-party-hardware_pps-tti-mx100qp.txt (1120 words)
# ✅ Kept hardware_third-party-hardware_r-s-hmp4030.txt (41 words)
# ✅ Kept hardware_third-party-hardware_tdk-lambda-genesys-series.txt (74 words)
# ✅ Kept hardware_third-party-hardware_toellner-toe8952-40.txt (308 words)
# ✅ Kept home_castle-versions.txt (59 words)
# ✅ Kept home_castle-versions_castle-5.txt (89 words)
# ✅ Kept home_castle-versions_castle-5_new-and-noteworthy.txt (854 words)
# ✅ Kept home_castle-versions_castle-5_specification.txt (1066 words)
# ✅ Kept home_castle-versions_castle-6.txt (237 words)
# ✅ Kept home_castle-versions_castle-6_mipi-interface-capabilities-on-castle-6.txt (1553 words)
# ✅ Kept home_castle-versions_castle-6_specification.txt (520 words)
# ✅ Kept home_castle-versions_castle-6_whats-new.txt (317 words)
# ✅ Kept home_crash-training_application-configurator-ui.txt (75 words)
# ✅ Kept home_crash-training_first-testcase.txt (100 words)
# ✅ Kept home_crash-training_your-castle-first-project.txt (135 words)
# ✅ Kept home_crash-training_your-castle-first-projecte486.txt (135 words)
# 🗑️ Deleted home_user-guide.txt (only 2 words)
# ✅ Kept home_user-guide_gradlesetuptousenexus.txt (331 words)
# ✅ Kept home_user-guide_makegitoversshandscpworkwithoutpassword.txt (890 words)
# 🗑️ Deleted product-lines.txt (only 2 words)
# 🗑️ Deleted product-lines_&quot;&quot;.txt (only 13 words)
# 🗑️ Deleted product-lines_active-safety.txt (only 2 words)
# 🗑️ Deleted product-lines_active-safety_honda-active-safety.txt (only 3 words)
# 🗑️ Deleted product-lines_camera-systems.txt (only 2 words)
# ✅ Kept product-lines_camera-systems_adapting-fw-to-capture-from-two-streams-during-runtime.txt (207 words)
# ✅ Kept product-lines_camera-systems_analog-video-de-interlacing.txt (859 words)
# ✅ Kept product-lines_camera-systems_automotive-computer-vision-features.txt (40 words)
# ✅ Kept product-lines_camera-systems_bmp-header-format.txt (397 words)
# ✅ Kept product-lines_camera-systems_building-a-video-frame-out-of-pixels-capture-feature-in-a-nutshell.txt (1415 words)
# ✅ Kept product-lines_camera-systems_cameras-hw-enhancements.txt (468 words)
# ✅ Kept product-lines_camera-systems_cameras-pip-design-considerations.txt (1531 words)
# ✅ Kept product-lines_camera-systems_dvs-induction.txt (1848 words)
# ✅ Kept product-lines_camera-systems_features-testing-manual-static-streaming-part.txt (1985 words)
# ✅ Kept product-lines_camera-systems_hud_audi_ppc_pip.txt (1207 words)
# ✅ Kept product-lines_camera-systems_hud_psa_ds3.txt (1194 words)
# ✅ Kept product-lines_camera-systems_hud_psa_ds3_test-bench-verification.txt (667 words)
# ✅ Kept product-lines_camera-systems_implementing-capture-feature-checklist.txt (2041 words)
# ✅ Kept product-lines_camera-systems_open-ldi-oldi.txt (68 words)
# ✅ Kept product-lines_camera-systems_quad-camera-module.txt (1315 words)
# ✅ Kept product-lines_camera-systems_quad-camera-module_bt-656-style-embedded-sync.txt (212 words)
# ✅ Kept product-lines_camera-systems_rvc-pip-v2-fault-box.txt (463 words)
# ✅ Kept product-lines_camera-systems_stream-capture-raw-videos.txt (2011 words)
# ✅ Kept product-lines_camera-systems_supported-image-processing-applications-in-c5-environment.txt (1408 words)
# ✅ Kept product-lines_camera-systems_svs-features-testing-manual.txt (3071 words)
# 🗑️ Deleted product-lines_camera-systems_svs-pip-validation.txt (only 3 words)
# 🗑️ Deleted product-lines_camera-systems_svs_gm_vpm-test-bench-design.txt (only 18 words)
# ✅ Kept product-lines_camera-systems_tools.txt (26 words)
# ✅ Kept product-lines_camera-systems_vdma-notes.txt (5859 words)
# ✅ Kept product-lines_camera-systems_video-interface-mediums.txt (2675 words)
# ✅ Kept product-lines_camera-systems_video-streaming-solution---user-manual.txt (2737 words)
# ✅ Kept product-lines_camera-systems_video_in-ip-core-architecture.txt (2189 words)
# ✅ Kept product-lines_camera-systems_yuv-rgb-conversion-methods.txt (895 words)
# ✅ Kept product-lines_cta-fri.txt (153 words)
# 🗑️ Deleted product-lines_cta-fri_testing-strategy.txt (only 2 words)
# 🗑️ Deleted product-lines_cta-fri_testing-strategy_artemis-evtp-testing-architecture.txt (only 4 words)
# ✅ Kept product-lines_front-camera.txt (139 words)
# ✅ Kept product-lines_front-camera_fc-frontcam-catalogue.txt (26 words)
# 🗑️ Deleted product-lines_front-camera_protocols.txt (only 1 words)
# ✅ Kept product-lines_front-camera_protocols_fc-mipc-mesp-documentation.txt (255 words)
# ✅ Kept product-lines_front-camera_protocols_meu-mobileeye-over-uart.txt (408 words)
# ✅ Kept product-lines_front-camera_protocols_mipc-protocol.txt (24 words)
# ✅ Kept product-lines_front-camera_protocols_road-environment-management.txt (138 words)
# ✅ Kept product-lines_front-camera_tools_multidbcfilesmergingscript.txt (186 words)
# ✅ Kept product-lines_front-camera_virtual-castle-canoesilkit-binding-for-mipc.txt (569 words)
# ✅ Kept product-lines_gm-vam-firmware-setup.txt (2036 words)
# ✅ Kept product-lines_itc.txt (93 words)
# ✅ Kept product-lines_itc_1---starting-a-project.txt (601 words)
# ✅ Kept product-lines_itc_itc-online-workshop.txt (34 words)
# ✅ Kept product-lines_mbm.txt (78 words)
# 🗑️ Deleted product-lines_mbm_integration-guide.txt (only 2 words)
# ✅ Kept product-lines_mbm_integration-guide_usefuldocumentforiointerfacinginradar.txt (46 words)
# 🗑️ Deleted product-lines_mbm_testing-strategy.txt (only 2 words)
# ✅ Kept product-lines_mbm_testing-strategy_radarreplaymode-hil.txt (1059 words)
# 🗑️ Deleted product-lines_mbm_testing-strategy_radarreplaymode.txt (only 10 words)
# ✅ Kept product-lines_upa.txt (373 words)
# 🗑️ Deleted product-lines_upa_discrete-sensors-ak-bric.txt (only 5 words)
# ✅ Kept product-lines_upa_discrete-sensors-ak-bric_ak---bric-sensor-lines.txt (1093 words)
# 🗑️ Deleted product-lines_upa_generic-tutorials.txt (only 2 words)
# 🗑️ Deleted product-lines_upa_generic-tutorials_castle---goto---vs6-user-training.txt (only 7 words)
# ✅ Kept product-lines_upa_generic-tutorials_upa-p4u-induction.txt (6982 words)
# 🗑️ Deleted product-lines_upa_hp-facelift-sensors.txt (only 3 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_-8-use-case-2---how-castle-maps-tofs-from-echo-echomm-in-cte-tree.txt (745 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_environment-setup-with-vs6.txt (1108 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_hp-facelift---castle-implementation.txt (399 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_hp-facelift-sensors---system-overview.txt (1476 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_hpfaceliftdualmeasurement.txt (1026 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_hpsensorscalculationoftoffromdistanceinmm.txt (541 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_lin-frame-transmission-order-for-hp-faclift-sensors.txt (1451 words)
# ✅ Kept product-lines_upa_hp-facelift-sensors_lin-frame-transmission-order-for-hp_fl-mseq_v3-7.txt (317 words)
# 🗑️ Deleted product-lines_upa_hp-sensors.txt (only 2 words)
# ✅ Kept product-lines_upa_hp-sensors_hp-sensors---general-requirements.txt (125 words)
# ✅ Kept product-lines_upa_hp-sensors_hp-sensors-diagnostics.txt (165 words)
# 🗑️ Deleted product-lines_upa_tools.txt (only 1 words)
# 🗑️ Deleted product-lines_upa_tools_daste.txt (only 1 words)
# ✅ Kept product-lines_upa_tools_daste_makedasteworkingonyourmachine.txt (596 words)
# ✅ Kept product-lines_upa_upa-castle-for-external-customers.txt (313 words)
# 🗑️ Deleted product-lines_upa_usv-sensors.txt (only 2 words)
# ✅ Kept product-lines_upa_usv-sensors_usv-sensors.txt (440 words)
# ✅ Kept product-lines_upa_usv-sensors_usv-sensors_-usv10-sensors---dsi3xc-commands-summary.txt (1321 words)
# ✅ Kept product-lines_upa_usv-sensors_usv-sensors_-usv10-sensors---simulation-concept.txt (1028 words)
# 🗑️ Deleted product-lines_upa_usv-sensors_usv-sensors_dsi3.txt (only 14 words)
# ✅ Kept product-lines_upa_usv-sensors_usv-sensors_usv-sensors---system-overview.txt (1141 words)
# 🗑️ Deleted product-lines_zc-zone-controller_zc-rn-piu-sweet500.txt (only 13 words)
# 🗑️ Deleted support.txt (only 1 words)
# 🗑️ Deleted support_cdv-sla.txt (only 2 words)
# ✅ Kept support_firmware-ticketing-process.txt (1214 words)
# ✅ Kept support_firmware-ticketing-process_core-alm---access-to-castle-project.txt (138 words)
# ✅ Kept support_firmware-ticketing-process_corealm-teamforge---create-account.txt (68 words)
# ✅ Kept support_reporting-problems.txt (24 words)
# 🗑️ Deleted support_troubleshooting.txt (only 1 words)
# 🗑️ Deleted support_troubleshooting_castle-6-rpu-troubleshooting.txt (only 4 words)
# ✅ Kept support_troubleshooting_castle-6-rpu-troubleshooting_rpu-back-trace.txt (203 words)
# ✅ Kept support_troubleshooting_castle-6-rpu-troubleshooting_rpu-busy-notifier.txt (121 words)
# ✅ Kept support_troubleshooting_castle-project-launchers.txt (124 words)
# ✅ Kept support_troubleshooting_castlepimpingsbackbutnoconnection.txt (264 words)
# ✅ Kept support_troubleshooting_configuremachineiptocommunicatewithcastle5.txt (289 words)
# ✅ Kept support_troubleshooting_how-to-keep-your-laptop-operating-overnight.txt (251 words)
# ✅ Kept support_troubleshooting_issuecastle5basepcbpoweronresetloop.txt (178 words)
# ✅ Kept support_troubleshooting_java-monitoring-crecte.txt (153 words)
# ✅ Kept support_troubleshooting_update-java-gradle-certificates.txt (303 words)
# ✅ Kept support_troubleshooting_updated-cacert-2-5-2024.txt (72 words)
# 🗑️ Deleted test-scripting.txt (only 2 words)
# ✅ Kept test-scripting_castleschoolminivideoseries.txt (28 words)
# 🗑️ Deleted test-scripting_castleschoolminivideoseries_config-and-config-appl.txt (only 8 words)
# ✅ Kept test-scripting_castleschoolminivideoseries_directvshilexecution.txt (528 words)
# ✅ Kept test-scripting_castleschoolminivideoseries_execution-unit-and-module-objects.txt (50 words)
# 🗑️ Deleted test-scripting_castleschoolminivideoseries_misc.txt (only 2 words)
# 🗑️ Deleted test-scripting_castleschoolminivideoseries_overview.txt (only 2 words)
# 🗑️ Deleted test-scripting_castleschoolminivideoseries_rack-slots-ip-addresses.txt (only 4 words)
# 🗑️ Deleted test-scripting_generic.txt (only 1 words)
# ✅ Kept test-scripting_generic_hilabort-tsreserror.txt (69 words)
# ✅ Kept test-scripting_generic_listenervssynchronousfunctionsfc.txt (90 words)
# ✅ Kept test-scripting_generic_taskletslifetimeandperformance.txt (71 words)
# 🗑️ Deleted test-scripting_generic_user-guide-test-programming.txt (only 2 words)
# 🗑️ Deleted test-scripting_hardware-apis.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-all-physical-links.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_networking-all-physical-links_checkifframeisreceivedwhencheckingasignalvalue.txt (463 words)
# ✅ Kept test-scripting_hardware-apis_networking-all-physical-links_createafaultoncommunicationlines.txt (22 words)
# ✅ Kept test-scripting_hardware-apis_networking-all-physical-links_howtosendmultiplexedsignalsinamultiplexedframecyclically.txt (154 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-bap.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_networking-bap_bapbapovercandeploymentinfirmwareprojects.txt (204 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-can.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-can_best-practices.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_autosarcanparsing-missingupdatebits.txt (332 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_bus-load-test-with-the-enhanced-can-controller.txt (40 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_can-driverinitandshutdown.txt (787 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_canbusfaults.txt (146 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_cancontrollerconfigurationcommonmistake.txt (340 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_candriverconfiguration.txt (72 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_canerrorssimulationincastle.txt (618 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_canfdbittimingconfiguration.txt (865 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_usage-of-muxconf-api-with-can.txt (127 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_best-practices_workingwithcandbcmultiplexedmessages.txt (181 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-can_integration-guide.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_integration-guide_activatingsinglewirecanontja1055t3transceiver.txt (303 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_integration-guide_bus-restart-error-in-bp.txt (68 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_integration-guide_can-fdsupport.txt (141 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_integration-guide_canbusterminalresistor.txt (109 words)
# ✅ Kept test-scripting_hardware-apis_networking-can_integration-guide_diagspy-50pinconnector.txt (97 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-diag.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-diag_best-practices.txt (only 8 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_best-practices_c5-diag.txt (62 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_best-practices_diagsynchronouscallinsteadoflistener.txt (218 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-diag_tutorials.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-diag_tutorials_diagnostic-integration.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_diagnostics-induction.txt (5753 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_ethernetdoip-object.txt (1198 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_integrate-security-algorithms-with-openssl.txt (992 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_integratesecurityalgorithmsembeddedindlls.txt (2357 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_key-calculation-in-direct-mode-using-python-cre-client.txt (293 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-diag_tutorials_odx-2-2-0.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-diag_tutorials_userguidetousesecurityaccessusingdllimplementation.txt (133 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet_best-practices.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_best-practices_changemacaddressesinethernetdriver.txt (180 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_best-practices_eth-brphymonitortaskbestpractice.txt (542 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_best-practices_ethernetbusoffhowtoenabledisablebroadrlinkstatus.txt (63 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_best-practices_ethernetsocketethernetserversocketoverview.txt (788 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet_integration-guide.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_integration-guide_broadrethernetconnection.txt (77 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_integration-guide_eth-brcanoeconfiguration.txt (340 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet_tutorials.txt (only 8 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_tutorials_castle5-ethernet-features.txt (127 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet_tutorials_cyber-security.txt (only 2 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-ethernet_tutorials_ethernet-socket-programming-in-castle.txt (only 5 words)
# ✅ Kept test-scripting_hardware-apis_networking-ethernet_tutorials_service-discovery.txt (2003 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-flexray.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-flexray_best-practices.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-flexray_best-practices_enablecrcsqcforflexray.txt (201 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-flexray_integration-guide.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_networking-flexray_integration-guide_bib46frbatching.txt (108 words)
# ✅ Kept test-scripting_hardware-apis_networking-flexray_integration-guide_castle5-flexrayfrpinassignment.txt (160 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-lin.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_networking-lin_testcaseadjustmentsfordifferentlindiagsessions.txt (741 words)
# 🗑️ Deleted test-scripting_hardware-apis_networking-xcp.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_networking-xcp_configurediagandxcptoworkonthesamemessagesviadynamiccom.txt (525 words)
# 🗑️ Deleted test-scripting_hardware-apis_platform-core.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_platform-core_checking-castle-messages-using-ensuremsg-api.txt (155 words)
# ✅ Kept test-scripting_hardware-apis_platform-core_procunit-apis.txt (306 words)
# ✅ Kept test-scripting_hardware-apis_platform-core_signalcoupling.txt (77 words)
# 🗑️ Deleted test-scripting_hardware-apis_platform-pulse-edge-monitor.txt (only 3 words)
# ✅ Kept test-scripting_hardware-apis_platform-pulse-edge-monitor_pulse-edge-monitor.txt (760 words)
# 🗑️ Deleted test-scripting_hardware-apis_platform-pwm-tester.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_platform-pwm-tester_c5-pwmmoduletesterguide.txt (470 words)
# 🗑️ Deleted test-scripting_hardware-apis_platform-spi-analyzer.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_platform-spi-analyzer_spi-analyzer.txt (368 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-cam.txt (only 1 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-cam_tutorials.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-cam_tutorials_fault-box-v1.txt (656 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-cam_video-capture-frame-rate-measure.txt (113 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-fc.txt (only 1 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-fc_integration-guide.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-fc_integration-guide_frontcamera-debugging-manual.txt (91 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-fc_tutorials.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-fc_tutorials_fc-changing-eyeq-version-in-generic-fw.txt (310 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-fc_tutorials_fc-interrupt-based-reset-request.txt (554 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-fc_tutorials_mipc_cfg-addon-in-fc-projects.txt (239 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-generic-ios.txt (only 2 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-generic-ios_tutorials.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-generic-ios_tutorials_vls-pipv1-user-guide.txt (365 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-uls.txt (only 8 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric.txt (only 5 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_-ak-sensors-sw-failures.txt (222 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_aksensorsv2.txt (434 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_bricsensorvsaksensor.txt (283 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-uls_generic.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_generic_continuousintegrationsupportvs6onmultiplepimsracks.txt (249 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_generic_goto-c5---user-guide.txt (479 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-uls_upa3-x-pip.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_led-module-user-guide.txt (62 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_led-testing-best-practices.txt (1541 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_sensorssupplylineissueinpip37.txt (163 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_sensorssupplyshorttogroundfailuresimulationtip.txt (255 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_swtestulslinmasterresistormustbeenabledforhpsensors.txt (159 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_upa-pip_3-7-features-and-apis.txt (532 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_upapip3837-currentsink.txt (436 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-uls_usv-pip.txt (only 2 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_usv-pip_-usv10-sensors---castle-apis.txt (668 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-uls_usv-pip_-usv10-sensors---sensors-mapping.txt (70 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-zonal.txt (only 1 words)
# 🗑️ Deleted test-scripting_hardware-apis_product-lines-zonal_tutorials.txt (only 1 words)
# ✅ Kept test-scripting_hardware-apis_product-lines-zonal_tutorials_zc-pip-user-guide.txt (453 words)
# ✅ Kept test-scripting_hardware-apis_toellner-power-supply.txt (139 words)
# ✅ Kept test-scripting_hardware-apis_toellner-power-supply_configure-primary-address.txt (100 words)
# ✅ Kept test-scripting_hardware-apis_toellner-power-supply_ControlPowerSupplyusingToeDriver.txt (120 words)
# ✅ Kept test-scripting_hardware-apis_toellner-power-supply_voltageprofilesusingpowersupplytoellner8815.txt (269 words)
# 🗑️ Deleted test-scripting_java_java-libraries.txt (only 8 words)
# 🗑️ Deleted test-scripting_java_java-libraries_best-practices.txt (only 2 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_addlistenertoamessage.txt (407 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_assertinsidejavalibrary.txt (24 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_better-approaches-to-design-fusion-testing-libraries.txt (1566 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_directandhilruncontextforthesameenglish.txt (69 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_dryrunwithdirectmodemethodssfc.txt (183 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_hilvsdirecttest-casescomparison.txt (250 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_Java-Examples.txt (221 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_locate-git-using-castle-util.txt (22 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_mutable-signals-global-variables.txt (273 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_newfeatureautopause.txt (94 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_pauseuntilleventusagewitheventfilterapi.txt (270 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_printfromlibrariestocte.txt (33 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_procunittaskletsolution.txt (210 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_runapythonscriptfromajavatestcase.txt (130 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_securityaccessformultiplepims.txt (192 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_taskletsandhilvsjavacommands.txt (226 words)
# 🗑️ Deleted test-scripting_java_java-libraries_best-practices_test-sequencing.txt (only 3 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_translatehandler.txt (333 words)
# ✅ Kept test-scripting_java_java-libraries_best-practices_work-with-multi-threads.txt (916 words)
# 🗑️ Deleted test-scripting_java_standard-libraries.txt (only 2 words)
# 🗑️ Deleted test-scripting_java_standard-libraries_can.txt (only 1 words)
# ✅ Kept test-scripting_java_standard-libraries_can_initializecan-fdforbipv9.txt (198 words)
# 🗑️ Deleted test-scripting_java_standard-libraries_generic.txt (only 1 words)
# ✅ Kept test-scripting_java_standard-libraries_power-supply-toellner.txt (150 words)
# ✅ Kept test-scripting_java_standard-libraries_stdlibsdependencyseparationfromcte.txt (1178 words)
# 🗑️ Deleted test-scripting_java_standard-libraries_swdl.txt (only 1 words)
# ✅ Kept test-scripting_java_standard-libraries_swdl_finalimplemnetationofswdllibrarysuccessfullymodedtocastlestandardlibs.txt (22 words)
# ✅ Kept test-scripting_java_standard-libraries_swdl_swdl.txt (519 words)
# ✅ Kept test-scripting_java_standard-libraries_swdl_swdltestingusingisystemscastlevaleoflashingtoolexeoranyotherswdltool.txt (625 words)
# 🗑️ Deleted test-scripting_python.txt (only 1 words)
# ✅ Kept test-scripting_python_annotationsdecorators-in-python.txt (127 words)
# ✅ Kept test-scripting_python_cre-python-client.txt (1876 words)
# 🗑️ Deleted test-scripting_tsxml.txt (only 1 words)
# ✅ Kept test-scripting_tsxml_directandhilexecutionmodewithtsxml.txt (385 words)
# ✅ Kept test-scripting_tsxml_fixing-the-pausecheck-errors.txt (60 words)
# ✅ Kept test-scripting_tsxml_itisgoodpracticetoperformadryruntestexecutionduringtestplanningphase.txt (302 words)
# ✅ Kept test-scripting_tsxml_skippauseandtimebasis.txt (335 words)
# ✅ Kept test-scripting_tsxml_supportingarraysintsxml.txt (34 words)
# ✅ Kept test-scripting_tsxml_taskletandtsxmldirectexecution.txt (105 words)
# 🗑️ Deleted test-scripting_tsxml_tsxml-integration.txt (only 3 words)
# ✅ Kept test-scripting_tsxml_tsxmltimervalue.txt (96 words)
# 🗑️ Deleted test-strategy.txt (only 8 words)
# 🗑️ Deleted test-strategy_certifications.txt (only 4 words)
# ✅ Kept test-strategy_certifications_qualification-kit.txt (480 words)
# ✅ Kept test-strategy_test-types.txt (805 words)
# ✅ Kept test-strategy_test-types_end-of-line-test-eolt.txt (155 words)
# ✅ Kept test-strategy_test-types_environmental-test-chamber.txt (63 words)
# ✅ Kept test-strategy_test-types_environmental-test-chamber_ft--menu.txt (641 words)
# ✅ Kept test-strategy_test-types_environmental-test-chamber_ft--menu_ft-mobile.txt (273 words)
# 🗑️ Deleted test-strategy_test-types_environmental-test.txt (only 2 words)
# 🗑️ Deleted test-strategy_test-types_environmental-test_interfacing.txt (only 1 words)
# 🗑️ Deleted test-strategy_test-types_environmental-test_interfacing_export-tdms.txt (only 2 words)
# ✅ Kept test-strategy_test-types_industrial-test.txt (137 words)
# ✅ Kept test-strategy_test-types_industrial-test_castleeol.txt (214 words)
# ✅ Kept test-strategy_test-types_industrial-test_castleeol_change-managment.txt (702 words)
# ✅ Kept test-strategy_test-types_industrial-test_castleeol_getting-started.txt (352 words)
# ✅ Kept test-strategy_test-types_industrial-test_drivers-ped.txt (190 words)
# ✅ Kept test-strategy_test-types_industrial-test_drivers-ped_1-itac-integration.txt (486 words)
# ✅ Kept test-strategy_test-types_industrial-test_drivers-ped_2-ip-remote-control-socket.txt (331 words)
# ✅ Kept test-strategy_test-types_industrial-test_drivers-ped_3-power-supply.txt (117 words)
# ✅ Kept test-strategy_test-types_industrial-test_drivers-ped_4-encoder.txt (252 words)
# ✅ Kept test-strategy_test-types_industrial-test_tips-tricks.txt (1053 words)
# ✅ Kept test-strategy_test-types_industrial-test_tips-tricks_c5r-analysis.txt (262 words)
# 🗑️ Deleted test-strategy_test-types_tooling_testing-strategy.txt (only 8 words)
# 🗑️ Deleted test-strategy_test-types_tooling_testing-strategy_testing-in-mars.txt (only 4 words)
# ✅ Kept test-strategy_user-projects-cicd_12---continous-integration-swe6.txt (388 words)
# ✅ Kept test-strategy_user-projects-cicd_cdv-e-sw-vvalidationserverc-hilmbt.txt (365 words)
# ✅ Kept test-strategy_user-projects-cicd_htmlpublisherplugininjenkinspreventsrunningjscript.txt (99 words)
# ✅ Kept test-strategy_user-projects-cicd_jenkinsbuildmonitorforc5userprojects.txt (35 words)
# ✅ Kept test-strategy_user-projects-cicd_mbttsecgprojectgerritverifyjenkinstaskspotentialtsxmlgenerationonserver.txt (89 words)
# ✅ Kept test-strategy_user-projects-cicd_settingupgerritverifyjobsforcastleuserprojects.txt (32 words)
# ✅ Kept test-strategy_user-projects-cicd_suggestiononcrosstpllocaldireicorystructureformbtcastlehilandsilenvironments.txt (467 words)
# 🗑️ Deleted tooling_lessons-learned_updatejavasrootcertificates.txt (only 13 words)
# 🗑️ Deleted tools.txt (only 1 words)
# 🗑️ Deleted tools_additional-tools.txt (only 5 words)
# ✅ Kept tools_additional-tools_08---tutorials-and-usecase.txt (3606 words)
# 🗑️ Deleted tools_additional-tools_doors-importer.txt (only 2 words)
# ✅ Kept tools_additional-tools_doors-importer_developsubsidiarytoolfordoors-importer.txt (308 words)
# ✅ Kept tools_additional-tools_doors-importer_exportingrequreiementsviadoorsimporter.txt (126 words)
# ✅ Kept tools_additional-tools_doors-importer_linkingondoors.txt (33 words)
# ✅ Kept tools_additional-tools_doors-importer_linkingondoorswhenimporteruiisnotlinkingwhileswtestspecmoduleisopen.txt (198 words)
# 🗑️ Deleted tools_additional-tools_its.txt (only 1 words)
# ✅ Kept tools_additional-tools_its_intuitive-testing-suite-installation.txt (334 words)
# 🗑️ Deleted tools_additional-tools_libgen.txt (only 1 words)
# ✅ Kept tools_additional-tools_libgen_usinglibgenanda2lfilestosupportecucalibrationinc5basedsoftwaretestprojects.txt (191 words)
# 🗑️ Deleted tools_additional-tools_other-tools.txt (only 2 words)
# ✅ Kept tools_additional-tools_public-sessions.txt (142 words)
# ✅ Kept tools_additional-tools_swtestdesigner-1.txt (46 words)
# ✅ Kept tools_additional-tools_swtestide-1.txt (112 words)
# 🗑️ Deleted tools_additional-tools_swtestide-1_architecture.txt (only 1 words)
# ✅ Kept tools_additional-tools_swtestide-1_cdvswoperationskpisbasedreviewmappingtoswtestsummary.txt (34 words)
# 🗑️ Deleted tools_additional-tools_swtestide-1_communication-server.txt (only 3 words)
# ✅ Kept tools_additional-tools_swtestide-1_plugin-system.txt (219 words)
# ✅ Kept tools_additional-tools_swtestide-1_plugin-system_ci-plugin.txt (179 words)
# 🗑️ Deleted tools_additional-tools_swtestide-1_plugin-system_cte-integration-plugin.txt (only 6 words)
# 🗑️ Deleted tools_additional-tools_swtestide-1_plugin-system_cteintegration-plugin.txt (only 6 words)
# ✅ Kept tools_additional-tools_swtestide-1_plugin-system_parkman-bluetooth-client-plugin.txt (197 words)
# 🗑️ Deleted tools_additional-tools_swtestide-1_tutorials.txt (only 1 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_bl60swtestideticketsmapping.txt (239 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_cdvswoperationskpisbasedreviewmappingtoswtestsummary.txt (209 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_doorsxlsxexportstotsxmlconversion.txt (148 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_gettingtestcoveragematrixintsxmlbasedprojects.txt (123 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_gettingtestgroupticketvdrmappingintsxmlbasedprojects.txt (1219 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_requirementanalysisintsxmlbasedprojectusingtoolsbaseline66.txt (916 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_swtestide461bl58includesnowfunctionalitytoreporttoolrelatedproblems.txt (138 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_testgroupcommentfeatureinswtestide.txt (183 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_tutorials-and-usecases.txt (3604 words)
# ✅ Kept tools_additional-tools_swtestide-1_tutorials_unlockinggmailandgdriveinteraction-swtestide490.txt (1119 words)
# ✅ Kept tools_additional-tools_swtestide-1_virtual-pim-concept.txt (48 words)
# ✅ Kept tools_additional-tools_tools-baseline-deployment.txt (254 words)
# 🗑️ Deleted tools_additional-tools_tsecg.txt (only 15 words)
# ✅ Kept tools_additional-tools_tsecg_tsecgmainresourcesproperties.txt (257 words)
# ✅ Kept tools_additional-tools_tsecg_vw-application-test-file-comparator-tool.txt (44 words)
# ✅ Kept tools_additional-tools_tutorials-and-usecases.txt (277 words)
# ✅ Kept tools_additional-tools_user-guide.txt (162 words)
# 🗑️ Deleted tools_additional-tools_user-tools.txt (only 8 words)
# 🗑️ Deleted tools_additional-tools_user-tools_c5r-java-reader.txt (only 3 words)
# ✅ Kept tools_castle-system-driver.txt (24 words)
# ✅ Kept tools_castle-system-driver_c-cre-client.txt (28 words)
# ✅ Kept tools_castle-system-driver_lv-cre-client.txt (32 words)
# 🗑️ Deleted tools_castle-view.txt (only 2 words)
# 🗑️ Deleted tools_castle-view_tutorials.txt (only 1 words)
# 🗑️ Deleted tools_castle-view_tutorials_user-guide-castleview.txt (only 13 words)
# 🗑️ Deleted tools_cre.txt (only 1 words)
# ✅ Kept tools_cre_hardware-configuration_connecttospecificpiminrack2.txt (93 words)
# 🗑️ Deleted tools_cre_test-configuration.txt (only 2 words)
# ✅ Kept tools_cre_test-configuration_howtocreatetwolauncherfileseachwithspecificlibraries.txt (287 words)
# ✅ Kept tools_cre_toolchain_cre-command-line.txt (60 words)
# ✅ Kept tools_cre_toolchain_cre-command-line_cre-headless-mode.txt (142 words)
# ✅ Kept tools_cre_toolchain_cre-command-line_cre-local-utilities.txt (68 words)
# ✅ Kept tools_cre_toolchain_cre-embedded-mode.txt (101 words)
# ✅ Kept tools_cre_toolchain_cre-mastre-client.txt (51 words)
# ✅ Kept tools_cre_toolchain_cre-mastre-client_castle-configuration-in-mastre.txt (86 words)
# ✅ Kept tools_cre_toolchain_cre-mastre-client_supported-castle-commands-in-mastre.txt (334 words)
# ✅ Kept tools_cre_toolchain_cre-messaging-apis.txt (134 words)
# ✅ Kept tools_cre_toolchain_cre-path-support-test-context.txt (118 words)
# ✅ Kept tools_cre_toolchain_cre-remote-java-client.txt (128 words)
# ✅ Kept tools_cre_toolchain_enhanced-test-features.txt (388 words)
# ✅ Kept tools_cre_toolchain_runtime-signal.txt (102 words)
# ✅ Kept tools_cre_toolchain_toolchain-structure-castle-users.txt (546 words)
# 🗑️ Deleted tools_cre_troubleshooting.txt (only 8 words)
# ✅ Kept tools_cre_troubleshooting_cannotconnecttorackmanagerafter3tries.txt (135 words)
# ✅ Kept tools_cre_troubleshooting_castle-6-fw-dlt.txt (40 words)
# ✅ Kept tools_cre_troubleshooting_fixobjectpathshortening.txt (96 words)
# ✅ Kept tools_cte-control.txt (38 words)
# 🗑️ Deleted tools_cte.txt (only 1 words)
# 🗑️ Deleted tools_cte_application-configurator.txt (only 1 words)
# 🗑️ Deleted tools_cte_application-configurator_troubleshooting.txt (only 2 words)
# ✅ Kept tools_cte_application-configurator_troubleshooting_arxml-integration-issue.txt (60 words)
# ✅ Kept tools_cte_application-configurator_troubleshooting_dbc-integration-issues.txt (124 words)
# 🗑️ Deleted tools_cte_application-configurator_tutorials.txt (only 1 words)
# ✅ Kept tools_cte_application-configurator_tutorials_add-multi-pim-solution-via-ui-configurator.txt (139 words)
# ✅ Kept tools_cte_application-configurator_tutorials_dynamic-configuration-ui.txt (469 words)
# 🗑️ Deleted tools_cte_interfacing.txt (only 1 words)
# 🗑️ Deleted tools_cte_interfacing_cte-interaction-dll.txt (only 3 words)
# 🗑️ Deleted tools_cte_interfacing_protocol-cte.txt (only 3 words)
# ✅ Kept tools_cte_interfacing_wrongserverpasswordclaimatclientloginofcastleeolftmenu.txt (395 words)
# 🗑️ Deleted tools_cte_troubleshooting.txt (only 2 words)
# ✅ Kept tools_cte_troubleshooting_cteapisnotresponding.txt (61 words)
# ✅ Kept tools_cte_troubleshooting_cteprojectconnectionfailed.txt (116 words)
# ✅ Kept tools_cte_troubleshooting_cterelease214-complainsaboutspectextsarenotunique.txt (164 words)
# ✅ Kept tools_cte_troubleshooting_fixingcteloginfault10.txt (151 words)
# ✅ Kept tools_cte_tutorials_add-startup-code-before-castle-launch.txt (69 words)
# ✅ Kept tools_cte_tutorials_castle5-cte-runningexecutingaloop.txt (107 words)
# ✅ Kept tools_cte_tutorials_cte-3-0-0.txt (194 words)
# ✅ Kept tools_cte_tutorials_newfeatureenqueuetest.txt (70 words)
# ✅ Kept tools_cte_tutorials_reloadcte.txt (155 words)
# ✅ Kept tools_cte_tutorials_signal-plotter.txt (115 words)
# ✅ Kept tools_cte_tutorials_tsxml-starter-plugin.txt (461 words)
# ✅ Kept tools_cte_tutorials_user-guide-cte.txt (35 words)
# ✅ Kept tools_deployment.txt (146 words)
# ✅ Kept tools_deployment_valeo-extern.txt (168 words)
# ✅ Kept tools_deployment_valeo-intern.txt (82 words)
# 🗑️ Deleted tools_external-tools-interfacing_canoe.txt (only 1 words)
# ✅ Kept tools_external-tools-interfacing_canoe_cre-canoe-client.txt (67 words)
# 🗑️ Deleted tools_external-tools-interfacing_robot-operating-system-ros.txt (only 4 words)
# ✅ Kept tools_external-tools-interfacing_robot-operating-system-ros_ros-delay-analysis.txt (620 words)
# ✅ Kept tools_external-tools-interfacing_robot-operating-system-ros_ros-jade.txt (473 words)
# 🗑️ Deleted tools_external-tools-interfacing_vosstrex.txt (only 1 words)
# ✅ Kept tools_external-tools-interfacing_vosstrex_vostrex.txt (1053 words)
# 🗑️ Deleted tools_pc-setup.txt (only 8 words)
# 🗑️ Deleted tools_pc-setup_offline-machines.txt (only 2 words)
# ✅ Kept tools_pc-setup_offline-machines_castle-project-packaging.txt (146 words)
# ✅ Kept tools_pc-setup_offline-machines_convert-project-to-run-on-offline-machine.txt (187 words)
# 🗑️ Deleted tools_pc-setup_tutorials.txt (only 1 words)
# 🗑️ Deleted tools_pc-setup_tutorials_castle-5-installer.txt (only 3 words)
# ✅ Kept tools_pc-setup_tutorials_castle5-project-initializer.txt (195 words)
# 🗑️ Deleted tools_pc-setup_tutorials_installation.txt (only 1 words)
# ✅ Kept tools_pc-setup_tutorials_mcafeefirewallblockscastlecommunication-ifexecptionruleisnotdeployed.txt (334 words)
# ✅ Kept tools_pc-setup_tutorials_rack-sharing-installation.txt (352 words)
# 🗑️ Deleted tools_third-party-tools.txt (only 8 words)
# 🗑️ Deleted tools_third-party-tools_adtf.txt (only 1 words)
# ✅ Kept tools_third-party-tools_adtf_adtf-datexporter-video.txt (1327 words)
# ✅ Kept tools_third-party-tools_adtf_dvscastle-adtftool.txt (33 words)
# ✅ Kept tools_third-party-tools_adtf_extractasciifromdatusingadtf.txt (149 words)
# 🗑️ Deleted tools_third-party-tools_beyond-compare.txt (only 2 words)
# ✅ Kept tools_third-party-tools_beyond-compare_beyondcomparespeedfoldercomparisontip.txt (173 words)
# ✅ Kept tools_third-party-tools_dlt-viewer.txt (205 words)
# 🗑️ Deleted tools_third-party-tools_doors.txt (only 1 words)
# ✅ Kept tools_third-party-tools_doors_applyfilteronrequirementmodule.txt (66 words)
# 🗑️ Deleted tools_third-party-tools_doors_doors-importer-tsxml-linking-im-and-export.txt (only 13 words)
# ✅ Kept tools_third-party-tools_doors_doorslinkingnotworking.txt (100 words)
# ✅ Kept tools_third-party-tools_doors_exportingrequirementmodulefromdoorsserver.txt (64 words)
# 🗑️ Deleted tools_third-party-tools_eclipse.txt (only 1 words)
# 🗑️ Deleted tools_third-party-tools_eclipse_eclipse.txt (only 1 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipseautocompleteissue.txt (48 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipsegitandlabeldecoration.txt (129 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipseoxygen.txt (275 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipseoxygen2.txt (76 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipsepluginpapyrusforuml.txt (48 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipseplugins.txt (61 words)
# ✅ Kept tools_third-party-tools_eclipse_eclipseworkspacecorruption.txt (37 words)
# ✅ Kept tools_third-party-tools_eclipse_fixingcrashedworkspaceineclipse4x.txt (52 words)
# ✅ Kept tools_third-party-tools_eclipse_formatjavacodeandaddjavadoc.txt (177 words)
# ✅ Kept tools_third-party-tools_eclipse_gerritconfigurationineclipse.txt (80 words)
# ✅ Kept tools_third-party-tools_eclipse_howtorevertcodefromlocalhistoryusingeclipse.txt (94 words)
# ✅ Kept tools_third-party-tools_eclipse_introductiontocorealmusinggitperspectiveineclipse.txt (57 words)
# ✅ Kept tools_third-party-tools_eclipse_oldjavaprojectscantbebuiltwithneweclipse.txt (85 words)
# ✅ Kept tools_third-party-tools_eclipse_removebuildconfigurationfromeclipsesdk.txt (35 words)
# ✅ Kept tools_third-party-tools_eclipse_runantscriptineclipse.txt (49 words)
# ✅ Kept tools_third-party-tools_eclipse_viewxmlfromeclipse.txt (32 words)
# 🗑️ Deleted tools_third-party-tools_emacs.txt (only 1 words)
# ✅ Kept tools_third-party-tools_emacs_emacstexteditorforwindows.txt (47 words)
# 🗑️ Deleted tools_third-party-tools_ethernet-utility.txt (only 1 words)
# ✅ Kept tools_third-party-tools_ethernet-utility_fastpingingusingtping.txt (124 words)
# 🗑️ Deleted tools_third-party-tools_git.txt (only 8 words)
# ✅ Kept tools_third-party-tools_git_avoidopeningchangeswhicharerelatedtoeachotherifthereisnoneedforthisrelation.txt (193 words)
# ✅ Kept tools_third-party-tools_git_badpracticestoavoidwhenusinggerrit.txt (947 words)
# ✅ Kept tools_third-party-tools_git_c5-project-versioning.txt (63 words)
# ✅ Kept tools_third-party-tools_git_cachingcredentialsforgitlfs.txt (39 words)
# ✅ Kept tools_third-party-tools_git_cloningsymboliclinkssymlinksfromgitonwindows.txt (91 words)
# ✅ Kept tools_third-party-tools_git_comparinggitbrancheswithyourcomparingtool.txt (75 words)
# ✅ Kept tools_third-party-tools_git_dealinginthemostsimplestwaywithgitincastleuserprojectsusecases.txt (274 words)
# ✅ Kept tools_third-party-tools_git_fetchinglargefilesfromcorealmprojectsusinggitlfs.txt (128 words)
# ✅ Kept tools_third-party-tools_git_fixgitlfsfiles.txt (55 words)
# ✅ Kept tools_third-party-tools_git_generate-gerrit-change-id.txt (93 words)
# 🗑️ Deleted tools_third-party-tools_git_gerritbestpractices.txt (only 10 words)
# ✅ Kept tools_third-party-tools_git_gerritmarkyourchangeaswork-in-progress.txt (170 words)
# ✅ Kept tools_third-party-tools_git_gerrituploadyourcommitasdraft.txt (196 words)
# ✅ Kept tools_third-party-tools_git_git-add-hunks-of-file.txt (683 words)
# ✅ Kept tools_third-party-tools_git_git-bundle.txt (349 words)
# ✅ Kept tools_third-party-tools_git_Git-Commit.txt (279 words)
# ✅ Kept tools_third-party-tools_git_git-create-multiple-copies-of-your-project-git-work-trees.txt (238 words)
# ✅ Kept tools_third-party-tools_git_git-hooks.txt (303 words)
# ✅ Kept tools_third-party-tools_git_git-how-to-retrieve-any-file-from-a-specific-commit-manually.txt (966 words)
# ✅ Kept tools_third-party-tools_git_git-import-and-filtering.txt (155 words)
# ✅ Kept tools_third-party-tools_git_git-most-common-issues-for-castle-users.txt (272 words)
# ✅ Kept tools_third-party-tools_git_git-submodules.txt (1059 words)
# ✅ Kept tools_third-party-tools_git_git.txt (543 words)
# ✅ Kept tools_third-party-tools_git_gitbashwrapslineincorruptedway.txt (100 words)
# ✅ Kept tools_third-party-tools_git_gitcherry-pickacommitfromanothergitrepository.txt (69 words)
# ✅ Kept tools_third-party-tools_git_gitclistageallmodifiedanddeletedfilesbutnotnewones.txt (67 words)
# ✅ Kept tools_third-party-tools_git_gitcommentswithchangeids-howtheyshouldlooklike-andwhattheyshouldcontain.txt (518 words)
# ✅ Kept tools_third-party-tools_git_githaveaversionedconfig.txt (96 words)
# ✅ Kept tools_third-party-tools_git_githowtotrackdirectoriesbutnottheirfileswithgit.txt (175 words)
# ✅ Kept tools_third-party-tools_git_gitlfsobjectoidnotfound.txt (96 words)
# ✅ Kept tools_third-party-tools_git_gitmergetwocommits.txt (60 words)
# ✅ Kept tools_third-party-tools_git_gitmigration-authornamechanging.txt (77 words)
# ✅ Kept tools_third-party-tools_git_gitproblemswithlongpathnames.txt (61 words)
# ✅ Kept tools_third-party-tools_git_gitpullbestpractice.txt (38 words)
# ✅ Kept tools_third-party-tools_git_gitrebasebranchontoanotherbranch.txt (90 words)
# ✅ Kept tools_third-party-tools_git_gitrecoveryfromhardreset.txt (76 words)
# 🗑️ Deleted tools_third-party-tools_git_gitresetspecificfile.txt (only 18 words)
# ✅ Kept tools_third-party-tools_git_gitshowhistoryforspecificfile.txt (23 words)
# ✅ Kept tools_third-party-tools_git_gitwhatsadetachedheadingit.txt (662 words)
# ✅ Kept tools_third-party-tools_git_hot-to-stage-multiple-test-items-tsxml-tsres-c5r-and-lfs-push-via-git-bash.txt (238 words)
# ✅ Kept tools_third-party-tools_git_mergingbranchesusinggitmergtool.txt (484 words)
# ✅ Kept tools_third-party-tools_git_nonlinearhistoryingitprojects.txt (67 words)
# ✅ Kept tools_third-party-tools_git_rebasingingerritandgitandcherry-pick.txt (462 words)
# ✅ Kept tools_third-party-tools_git_restoringdeletedbranchescommits.txt (101 words)
# ✅ Kept tools_third-party-tools_git_reviewadditionofbinaryfilestogit.txt (198 words)
# ✅ Kept tools_third-party-tools_git_usedebuginfowithgitcommands.txt (82 words)
# ✅ Kept tools_third-party-tools_git_user-project-using-git.txt (322 words)
# 🗑️ Deleted tools_third-party-tools_go.txt (only 1 words)
# 🗑️ Deleted tools_third-party-tools_google-workspace.txt (only 2 words)
# 🗑️ Deleted tools_third-party-tools_google-workspace_cloud-search.txt (only 2 words)
# ✅ Kept tools_third-party-tools_google-workspace_cloud-search_usinggooglecloudsearchasyourdefaultchromesearchengine.txt (364 words)
# 🗑️ Deleted tools_third-party-tools_google-workspace_drive.txt (only 1 words)
# ✅ Kept tools_third-party-tools_google-workspace_drive_howtouploadlargesizefilesongdriveovernight.txt (219 words)
# 🗑️ Deleted tools_third-party-tools_google-workspace_gmail.txt (only 1 words)
# ✅ Kept tools_third-party-tools_google-workspace_gmail_listingarchivedemailsingmail.txt (21 words)
# 🗑️ Deleted tools_third-party-tools_google-workspace_sheets.txt (only 1 words)
# ✅ Kept tools_third-party-tools_google-workspace_sheets_googlesheetsconcatenatecellswithnewline.txt (20 words)
# ✅ Kept tools_third-party-tools_go_goprogramminglanguage.txt (46 words)
# 🗑️ Deleted tools_third-party-tools_gradle.txt (only 1 words)
# ✅ Kept tools_third-party-tools_gradle_gradle-daemon-timeout.txt (131 words)
# ✅ Kept tools_third-party-tools_gradle_gradletaskalwaysup-to-date.txt (130 words)
# 🗑️ Deleted tools_third-party-tools_hex-editor.txt (only 2 words)
# ✅ Kept tools_third-party-tools_hex-editor_ausefulhexeditorwxhexeditor.txt (35 words)
# ✅ Kept tools_third-party-tools_hex-editor_handy-hex-editor-viewer.txt (63 words)
# 🗑️ Deleted tools_third-party-tools_java.txt (only 1 words)
# ✅ Kept tools_third-party-tools_java_addinglocksandsynchronizedmethodsinjava.txt (53 words)
# ✅ Kept tools_third-party-tools_java_assertionsinjava.txt (87 words)
# ✅ Kept tools_third-party-tools_java_briefintroonjavanativeinterfacejni.txt (1004 words)
# ✅ Kept tools_third-party-tools_java_convertintegertohexstringwithcertainnumberofdigitsinjava.txt (62 words)
# ✅ Kept tools_third-party-tools_java_exportmainclasstoexecutablejarineclipse.txt (99 words)
# ✅ Kept tools_third-party-tools_java_isjavapass-by-referenceorpass-by-value.txt (29 words)
# ✅ Kept tools_third-party-tools_java_java-shutdown-hook.txt (132 words)
# ✅ Kept tools_third-party-tools_java_javaoophints.txt (1039 words)
# ✅ Kept tools_third-party-tools_java_javaunittestcodecoverage.txt (277 words)
# ✅ Kept tools_third-party-tools_java_javaunittesting-asserts.txt (253 words)
# ✅ Kept tools_third-party-tools_java_javaverygoodlearningcourse.txt (41 words)
# ✅ Kept tools_third-party-tools_java_javavirtualmachine.txt (261 words)
# ✅ Kept tools_third-party-tools_java_javawexevsjavaexe.txt (82 words)
# ✅ Kept tools_third-party-tools_java_jaxbxmljavaconvertion.txt (734 words)
# ✅ Kept tools_third-party-tools_java_jvm-monitoring.txt (21 words)
# ✅ Kept tools_third-party-tools_java_lambdaexpression.txt (928 words)
# ✅ Kept tools_third-party-tools_java_matchgroupsbynameinregularexpressioninjava.txt (52 words)
# ✅ Kept tools_third-party-tools_java_parseandeditxmlfilesinjava.txt (221 words)
# ✅ Kept tools_third-party-tools_java_runpythonpatchfromjavaprogram.txt (117 words)
# ✅ Kept tools_third-party-tools_java_runuiinanotherthreadjava.txt (46 words)
# ✅ Kept tools_third-party-tools_java_useful-java-conversions.txt (187 words)
# ✅ Kept tools_third-party-tools_java_usingstreamstoaddtexttoeachelementinsetofstringsjava.txt (42 words)
# ✅ Kept tools_third-party-tools_linux-os_batchfilesandshellscripting.txt (38 words)
# ✅ Kept tools_third-party-tools_linux-os_changeinfilescontentusingbash.txt (23 words)
# ✅ Kept tools_third-party-tools_linux-os_copyerror-thefilenamewouldbetoolongforthedestinationfolder.txt (175 words)
# ✅ Kept tools_third-party-tools_linux-os_debugmissinglibsoonlinuxusinglddcommand.txt (373 words)
# ✅ Kept tools_third-party-tools_linux-os_gitdifffilesinmeld.txt (53 words)
# ✅ Kept tools_third-party-tools_linux-os_inotify.txt (773 words)
# 🗑️ Deleted tools_third-party-tools_linux-os_linux-file-systems.txt (only 3 words)
# ✅ Kept tools_third-party-tools_linux-os_linuxlistrecursivelywithabsolutepath.txt (51 words)
# ✅ Kept tools_third-party-tools_linux-os_netcatasasimplewebserver.txt (240 words)
# ✅ Kept tools_third-party-tools_linux-os_removetrailingwhitespaces.txt (54 words)
# 🗑️ Deleted tools_third-party-tools_logic-analyzer.txt (only 1 words)
# ✅ Kept tools_third-party-tools_logic-analyzer_logicanalyzerusbee.txt (39 words)
# 🗑️ Deleted tools_third-party-tools_notepad.txt (only 1 words)
# ✅ Kept tools_third-party-tools_notepad_commentsinnotepad.txt (30 words)
# ✅ Kept tools_third-party-tools_notepad_notepadeditmenu.txt (33 words)
# 🗑️ Deleted tools_third-party-tools_notepad_notepadtipsandtricks.txt (only 18 words)
# 🗑️ Deleted tools_third-party-tools_regular-expressions.txt (only 2 words)
# 🗑️ Deleted tools_third-party-tools_regular-expressions_regular-expressions.txt (only 7 words)
# 🗑️ Deleted tools_third-party-tools_screenshot.txt (only 1 words)
# 🗑️ Deleted tools_third-party-tools_screenshot_screenshottool.txt (only 18 words)
# 🗑️ Deleted tools_third-party-tools_vector.txt (only 1 words)
# 🗑️ Deleted tools_third-party-tools_vector_arxml-editor.txt (only 2 words)
# ✅ Kept tools_third-party-tools_vector_arxml-editor_howtoeditarxmlfile.txt (90 words)
# 🗑️ Deleted tools_third-party-tools_vector_canoe.txt (only 1 words)
# ✅ Kept tools_third-party-tools_vector_canoe_automatedcanframecyclictimetestusingcapl.txt (677 words)
# ✅ Kept tools_third-party-tools_vector_canoe_canalyzer-ig.txt (29 words)
# ✅ Kept tools_third-party-tools_vector_canoe_canoeastcpserver.txt (99 words)
# ✅ Kept tools_third-party-tools_vector_canoe_canoeconfigurationforethernetcaplcode.txt (172 words)
# ✅ Kept tools_third-party-tools_vector_canoe_canoeconfigurecanoeasapassivecannode.txt (81 words)
# ✅ Kept tools_third-party-tools_vector_canoe_canoelinconfigurelinmasterigincanoe.txt (55 words)
# ✅ Kept tools_third-party-tools_vector_canoe_communicationwithcanoe.txt (1466 words)
# ✅ Kept tools_third-party-tools_vector_canoe_genericethernetcaplcode.txt (514 words)
# ✅ Kept tools_third-party-tools_vector_canoe_lin20-canoe-masterresistor.txt (87 words)
# ✅ Kept tools_third-party-tools_vector_canoe_sendcyclicethernetpacketipv4ipv6usingcaplcode.txt (309 words)
# ✅ Kept tools_third-party-tools_vector_canoe_simulate-ethernet-nodes-in-arxml.txt (151 words)
# ✅ Kept tools_third-party-tools_vector_canoe_splitting-canoe-trace-by-time.txt (127 words)
# 🗑️ Deleted tools_third-party-tools_vector_canoe_vector-capl-dll-development.txt (only 4 words)
# 🗑️ Deleted tools_third-party-tools_vector_dbc.txt (only 1 words)
# ✅ Kept tools_third-party-tools_vector_dbc_addingsignaltodbc.txt (43 words)
# 🗑️ Deleted tools_third-party-tools_windows-os.txt (only 2 words)
# 🗑️ Deleted tools_third-party-tools_windows-os_addingbashlinuxsubsystemtowindows10.txt (only 16 words)
# ✅ Kept tools_third-party-tools_windows-os_compilepythonscriptstostandalonewindowsexecutableexe.txt (189 words)
# ✅ Kept tools_third-party-tools_windows-os_dlldependencies.txt (46 words)
# ✅ Kept tools_third-party-tools_windows-os_fix-telnet-scrolling-issue-in-windows-terminal-wt.txt (64 words)
# ✅ Kept tools_third-party-tools_windows-os_powershellscriptforpcperformancemonitoring.txt (30 words)
# ✅ Kept tools_third-party-tools_windows-os_remotedesktopconnectionfullscreen.txt (62 words)
# ✅ Kept tools_third-party-tools_windows-os_remotely-control-powersupply.txt (216 words)
# ✅ Kept tools_third-party-tools_windows-os_set-windows-user-environment-variable-permanently-with-powershell.txt (96 words)
# ✅ Kept tools_third-party-tools_windows-os_staticvsdynamicpythonscriptcompilingintoexecutableexefile.txt (91 words)
# ✅ Kept tools_third-party-tools_windows-os_suppresswindowsterminaltitleupdates.txt (47 words)
# 🗑️ Deleted tools_third-party-tools_wireshark.txt (only 1 words)
# ✅ Kept tools_third-party-tools_wireshark_defineethernetdataprotocolforwireshark.txt (48 words)
# ✅ Kept tools_third-party-tools_wireshark_wiresharkdissector.txt (7766 words)

# %%
import os

# %%
import os
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

pages_folder = "pages"
summaries_folder = "summaries"
os.makedirs(summaries_folder, exist_ok=True)

# Load docs from pages folder
docs = []
for filename in os.listdir(pages_folder):
    if filename.endswith(".txt"):
        filepath = os.path.join(pages_folder, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            content = f.read().strip()
        if content:
            docs.append(Document(page_content=content, metadata={"source": filename}))

print(f"✅ Loaded {len(docs)} documents from {pages_folder}")

# Define chain
chain = (
    {"doc": lambda x: x.page_content, "name": lambda x: x.metadata["source"]}
    | ChatPromptTemplate.from_template(
        "You are summarizing a document extracted from a file.\n\n"
        "File Name: {name}\n\n"
        "Document Content:\n{doc}\n\n"
        "Please provide a clear, concise summary."
    )
    | ChatOpenAI(model="gpt-4o-mini", max_retries=2)  # ✅ updated model + retries
    | StrOutputParser()
)

# Run summarization with lower concurrency
summaries = chain.batch(docs, {"max_concurrency": 2})

# Save each summary
for doc, summary in zip(docs, summaries):
    filename = doc.metadata["source"]
    summary_filename = filename.replace(".txt", ".summary.txt")
    summary_path = os.path.join(summaries_folder, summary_filename)
    with open(summary_path, "w", encoding="utf-8") as f:
        f.write(f"Source File: {filename}\n\nSummary:\n{summary}")
    print(f"📝 Saved summary: {summary_path}")
# Out:
# ✅ Loaded 541 documents from pages
# 📝 Saved summary: summaries\about-us_the-team.summary.txt
# 📝 Saved summary: summaries\Artemis_v6.1_PIP_Front_Connectors_IOs.summary.txt
# 📝 Saved summary: summaries\CRE_arguments.summary.txt
# 📝 Saved summary: summaries\general-topics_autosar_autosar42containersecuredpdus.summary.txt
# 📝 Saved summary: summaries\general-topics_castle-6-bip-ethernet-interface.summary.txt
# 📝 Saved summary: summaries\general-topics_castle-programming-adaptor.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_lwip-v6-neighbor-discovery.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_simulate-nodes-from-arxml-in-canoe.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_tcp.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_tcpsegmentation.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_tls-in-castle.summary.txt
# 📝 Saved summary: summaries\general-topics_ethernet_understandmaclayer.summary.txt
# 📝 Saved summary: summaries\general-topics_flexray_flexray-diag.summary.txt
# 📝 Saved summary: summaries\general-topics_flexray_flexrayonoscilloscope.summary.txt
# 📝 Saved summary: summaries\general-topics_i2c_i2c-bus-pullup-resistor-calculation.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2_mipi-protocols.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2_mipi-protocols_mipi-csi-2-2-of-2.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2_mipi-protocols_mipi-csi-2.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2_mipi-protocols_mipi-csi2-part-1.summary.txt
# 📝 Saved summary: summaries\general-topics_mipi-csi-2_mipi-protocols_mipi-csi2-part-2.summary.txt
# 📝 Saved summary: summaries\general-topics_video-formats_understandingyuvvideodataformats.summary.txt
# 📝 Saved summary: summaries\hardware.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_baseboardsoftreset.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_basis-5-1.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_basis-5-2.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_basis-5-3.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_bootloader_bootloaderflasherscript.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_bootloader_castle5clockmodulebootfailure.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_calibration.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_calibration_calibration.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_basis_waveformgenerator.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bip.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bip_bip-4-6.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bip_bip-4-6_can-sw-single-line.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bip_bip-4-7.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bp-backplane_serial-debug_c5-debugging-backplane-rs232.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_bp-backplane_serial-debug_c5rackserialportconnection.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_embase-1.summary.txt
# 📝 Saved summary: summaries\hardware_castle-5_versioning.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_base_base-board-soft-reset-c6.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_base_base-r06-x-as-pcie-card.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_base_base-rc06-23.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_base_base-rc06-24.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_bip.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_bip_hw-patches_bip-switch-jtag-header.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_bip_hw-patches_mv-switch-port-9-10g-2-5g.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_castle-6-dbs-daughter-boards.summary.txt
# 📝 Saved summary: summaries\hardware_castle-6_serial-debug.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_cdoe-contact-design-of-experiment.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_dms_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_env_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_front-camera_frontcamera_pip_v2.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_front-camera_frontcamera_pip_v3.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_hud_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_rlt_pip--rlt--r01-0.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_scala_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_camerafaultboxes.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_gm_ti.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_rcvv2-0.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_rcvv2-0_two-hw-patches.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_svs_rvcv1-0.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_tcm_tcm-epip-rev-2-1.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_tcm_tcm-epip-rev-2.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_tcm_tcm-eval-r01-0.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_telematics_pip-tcu-daimler-artemis.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_telematics_pip-tcu-vw-conmod2.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_ultrasonic_upa_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_ultrasonic_upa_uls-upit-ak-sensor-test.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_ultrasonic_usv10.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_ultrasonic_usv10_pip.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_ultrasonic_usv10_usv10-2-wire-master-r05-0.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_vls_vls_pip_v1.summary.txt
# 📝 Saved summary: summaries\hardware_pip-product-interface-pcbs_zonal-controller_zonal-pip-v000093_2.summary.txt
# 📝 Saved summary: summaries\hardware_racks.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_keysight-data-acquisition-switch-unit-34970a.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_keysight-io-libraries-suite.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_keysight-rf-sg-n9310a.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_keysight-wg-33511b.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_pps-tti-mx100qp.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_r-s-hmp4030.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_tdk-lambda-genesys-series.summary.txt
# 📝 Saved summary: summaries\hardware_third-party-hardware_toellner-toe8952-40.summary.txt
# 📝 Saved summary: summaries\home_castle-versions.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-5.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-5_new-and-noteworthy.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-5_specification.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-6.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-6_mipi-interface-capabilities-on-castle-6.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-6_specification.summary.txt
# 📝 Saved summary: summaries\home_castle-versions_castle-6_whats-new.summary.txt
# 📝 Saved summary: summaries\home_crash-training.summary.txt
# 📝 Saved summary: summaries\home_crash-training_application-configurator-ui.summary.txt
# 📝 Saved summary: summaries\home_crash-training_first-testcase.summary.txt
# 📝 Saved summary: summaries\home_crash-training_your-castle-first-project.summary.txt
# 📝 Saved summary: summaries\home_crash-training_your-castle-first-projecte486.summary.txt
# 📝 Saved summary: summaries\home_user-guide_castle-installer.summary.txt
# 📝 Saved summary: summaries\home_user-guide_gradlesetuptousenexus.summary.txt
# 📝 Saved summary: summaries\home_user-guide_makegitoversshandscpworkwithoutpassword.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_adapting-fw-to-capture-from-two-streams-during-runtime.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_analog-video-de-interlacing.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_automotive-computer-vision-features.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_bmp-header-format.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_building-a-video-frame-out-of-pixels-capture-feature-in-a-nutshell.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_cameras-hw-enhancements.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_cameras-pip-design-considerations.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_dvs-induction.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_features-testing-manual-static-streaming-part.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_hud_audi_ppc_pip.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_hud_psa_ds3.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_hud_psa_ds3_test-bench-verification.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_implementing-capture-feature-checklist.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_open-ldi-oldi.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_quad-camera-module.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_quad-camera-module_bt-656-style-embedded-sync.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_rvc-pip-v2-fault-box.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_stream-capture-raw-videos.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_supported-image-processing-applications-in-c5-environment.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_svs-features-testing-manual.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_tools.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_vdma-notes.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_video-interface-mediums.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_video-streaming-solution.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_video_in-ip-core-architecture.summary.txt
# 📝 Saved summary: summaries\product-lines_camera-systems_yuv-rgb-conversion-methods.summary.txt
# 📝 Saved summary: summaries\product-lines_cta-fri.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_fc-frontcam-catalogue.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_protocols_fc-mipc-mesp-documentation.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_protocols_meu-mobileeye-over-uart.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_protocols_mipc-protocol.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_protocols_road-environment-management.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_tools_multidbcfilesmergingscript.summary.txt
# 📝 Saved summary: summaries\product-lines_front-camera_virtual-castle-canoesilkit-binding-for-mipc.summary.txt
# 📝 Saved summary: summaries\product-lines_gm-vam-firmware-setup.summary.txt
# 📝 Saved summary: summaries\product-lines_itc.summary.txt
# 📝 Saved summary: summaries\product-lines_itc_1.summary.txt
# 📝 Saved summary: summaries\product-lines_itc_itc-online-workshop.summary.txt
# 📝 Saved summary: summaries\product-lines_mbm.summary.txt
# 📝 Saved summary: summaries\product-lines_mbm_integration-guide_usefuldocumentforiointerfacinginradar.summary.txt
# 📝 Saved summary: summaries\product-lines_mbm_testing-strategy_radarreplaymode-hil.summary.txt
# 📝 Saved summary: summaries\product-lines_upa.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_discrete-sensors-ak-bric_ak.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_generic-tutorials_upa-p4u-induction.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_-8-use-case-2.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_environment-setup-with-vs6.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_hp-facelift-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_hp-facelift.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_hpfaceliftdualmeasurement.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_hpsensorscalculationoftoffromdistanceinmm.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_lin-frame-transmission-order-for-hp-faclift-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-facelift-sensors_lin-frame-transmission-order-for-hp_fl-mseq_v3-7.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-sensors_hp-sensors-diagnostics.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_hp-sensors_hp-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_tools_daste_makedasteworkingonyourmachine.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_upa-castle-for-external-customers.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_usv-sensors_usv-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_usv-sensors_usv-sensors_-usv10-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_upa_usv-sensors_usv-sensors_usv-sensors.summary.txt
# 📝 Saved summary: summaries\product-lines_zc-zone-controller.summary.txt
# 📝 Saved summary: summaries\support_datasheets-for-castle-hw.summary.txt
# 📝 Saved summary: summaries\support_firmware-ticketing-process.summary.txt
# 📝 Saved summary: summaries\support_firmware-ticketing-process_core-alm.summary.txt
# 📝 Saved summary: summaries\support_firmware-ticketing-process_corealm-teamforge.summary.txt
# 📝 Saved summary: summaries\support_reporting-problems.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_castle-6-rpu-troubleshooting_rpu-back-trace.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_castle-6-rpu-troubleshooting_rpu-busy-notifier.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_castle-project-launchers.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_castlepimpingsbackbutnoconnection.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_configuremachineiptocommunicatewithcastle5.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_how-to-keep-your-laptop-operating-overnight.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_issuecastle5basepcbpoweronresetloop.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_java-monitoring-crecte.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_update-java-gradle-certificates.summary.txt
# 📝 Saved summary: summaries\support_troubleshooting_updated-cacert-2-5-2024.summary.txt
# 📝 Saved summary: summaries\test-scripting_castleschoolminivideoseries.summary.txt
# 📝 Saved summary: summaries\test-scripting_castleschoolminivideoseries_directvshilexecution.summary.txt
# 📝 Saved summary: summaries\test-scripting_castleschoolminivideoseries_execution-unit-and-module-objects.summary.txt
# 📝 Saved summary: summaries\test-scripting_generic_hilabort-tsreserror.summary.txt
# 📝 Saved summary: summaries\test-scripting_generic_listenervssynchronousfunctionsfc.summary.txt
# 📝 Saved summary: summaries\test-scripting_generic_taskletslifetimeandperformance.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-all-physical-links_checkifframeisreceivedwhencheckingasignalvalue.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-all-physical-links_createafaultoncommunicationlines.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-all-physical-links_howtosendmultiplexedsignalsinamultiplexedframecyclically.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-bap_bapbapovercandeploymentinfirmwareprojects.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_autosarcanparsing-missingupdatebits.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_bus-load-test-with-the-enhanced-can-controller.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_can-driverinitandshutdown.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_canbusfaults.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_cancontrollerconfigurationcommonmistake.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_candriverconfiguration.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_canerrorssimulationincastle.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_canfdbittimingconfiguration.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_usage-of-muxconf-api-with-can.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_best-practices_workingwithcandbcmultiplexedmessages.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_integration-guide_activatingsinglewirecanontja1055t3transceiver.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_integration-guide_bus-restart-error-in-bp.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_integration-guide_can-fdsupport.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_integration-guide_canbusterminalresistor.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-can_integration-guide_diagspy-50pinconnector.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_best-practices_c5-diag.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_best-practices_diagsynchronouscallinsteadoflistener.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_diagnostics-induction.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_ethernetdoip-object.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_integrate-security-algorithms-with-openssl.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_integratesecurityalgorithmsembeddedindlls.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_key-calculation-in-direct-mode-using-python-cre-client.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-diag_tutorials_userguidetousesecurityaccessusingdllimplementation.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_best-practices_changemacaddressesinethernetdriver.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_best-practices_eth-brphymonitortaskbestpractice.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_best-practices_ethernetbusoffhowtoenabledisablebroadrlinkstatus.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_best-practices_ethernetsocketethernetserversocketoverview.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_integration-guide_broadrethernetconnection.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_integration-guide_eth-brcanoeconfiguration.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_tutorials_castle5-ethernet-features.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-ethernet_tutorials_service-discovery.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-flexray_best-practices_enablecrcsqcforflexray.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-flexray_integration-guide_bib46frbatching.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-flexray_integration-guide_castle5-flexrayfrpinassignment.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-lin_testcaseadjustmentsfordifferentlindiagsessions.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_networking-xcp_configurediagandxcptoworkonthesamemessagesviadynamiccom.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-core_checking-castle-messages-using-ensuremsg-api.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-core_procunit-apis.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-core_signalcoupling.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-pulse-edge-monitor_pulse-edge-monitor.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-pwm-tester_c5-pwmmoduletesterguide.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_platform-spi-analyzer_spi-analyzer.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-cam_tutorials_fault-box-v1.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-cam_tutorials_storing-the-captured-image-to-ecu-within-the-test-case-hil-mode.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-cam_video-capture-frame-rate-measure.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-fc_integration-guide_frontcamera-debugging-manual.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-fc_tutorials_fc-changing-eyeq-version-in-generic-fw.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-fc_tutorials_fc-interrupt-based-reset-request.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-fc_tutorials_mipc_cfg-addon-in-fc-projects.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-generic-ios_tutorials_vls-pipv1-user-guide.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_-ak-sensor.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_-ak-sensors-sw-failures.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_aksensorsv2.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_discrete-sensors-ak-bric_bricsensorvsaksensor.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_generic_continuousintegrationsupportvs6onmultiplepimsracks.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_generic_goto-c5.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_led-module-user-guide.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_led-testing-best-practices.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_sensorssupplylineissueinpip37.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_sensorssupplyshorttogroundfailuresimulationtip.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_swtestulslinmasterresistormustbeenabledforhpsensors.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_upa-pip_3-7-features-and-apis.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_upa3-x-pip_upapip3837-currentsink.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-uls_usv-pip_-usv10-sensors.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_product-lines-zonal_tutorials_zc-pip-user-guide.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_toellner-power-supply.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_toellner-power-supply_configure-primary-address.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_toellner-power-supply_ControlPowerSupplyusingToeDriver.summary.txt
# 📝 Saved summary: summaries\test-scripting_hardware-apis_toellner-power-supply_voltageprofilesusingpowersupplytoellner8815.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_addlistenertoamessage.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_assertinsidejavalibrary.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_better-approaches-to-design-fusion-testing-libraries.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_directandhilruncontextforthesameenglish.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_dryrunwithdirectmodemethodssfc.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_hilvsdirecttest-casescomparison.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_Java-Examples.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_locate-git-using-castle-util.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_mutable-signals-global-variables.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_newfeatureautopause.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_pauseuntilleventusagewitheventfilterapi.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_printfromlibrariestocte.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_procunittaskletsolution.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_runapythonscriptfromajavatestcase.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_securityaccessformultiplepims.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_taskletsandhilvsjavacommands.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_translatehandler.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_java-libraries_best-practices_work-with-multi-threads.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_can_initializecan-fdforbipv9.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_generic_fillingtsxmlheaderusingstandardlibrarycastletestenvstdlibgenerictsxmlmetadatalibv1.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_power-supply-toellner.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_stdlibsdependencyseparationfromcte.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_swdl_finalimplemnetationofswdllibrarysuccessfullymodedtocastlestandardlibs.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_swdl_swdl.summary.txt
# 📝 Saved summary: summaries\test-scripting_java_standard-libraries_swdl_swdltestingusingisystemscastlevaleoflashingtoolexeoranyotherswdltool.summary.txt
# 📝 Saved summary: summaries\test-scripting_python_annotationsdecorators-in-python.summary.txt
# 📝 Saved summary: summaries\test-scripting_python_cre-python-client.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_directandhilexecutionmodewithtsxml.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_fixing-the-pausecheck-errors.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_itisgoodpracticetoperformadryruntestexecutionduringtestplanningphase.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_skippauseandtimebasis.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_supportingarraysintsxml.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_taskletandtsxmldirectexecution.summary.txt
# 📝 Saved summary: summaries\test-scripting_tsxml_tsxmltimervalue.summary.txt
# 📝 Saved summary: summaries\test-strategy_certifications_qualification-kit.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_end-of-line-test-eolt.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_environmental-test-chamber.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_environmental-test-chamber_ft--menu.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_environmental-test-chamber_ft--menu_ft-mobile.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_castleeol.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_castleeol_change-managment.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_castleeol_getting-started.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_drivers-ped.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_drivers-ped_1-itac-integration.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_drivers-ped_2-ip-remote-control-socket.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_drivers-ped_3-power-supply.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_drivers-ped_4-encoder.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_tips-tricks.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_industrial-test_tips-tricks_c5r-analysis.summary.txt
# 📝 Saved summary: summaries\test-strategy_test-types_tooling.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_12.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_cdv-e-sw-vvalidationserverc-hilmbt.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_htmlpublisherplugininjenkinspreventsrunningjscript.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_jenkinsbuildmonitorforc5userprojects.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_mbttsecgprojectgerritverifyjenkinstaskspotentialtsxmlgenerationonserver.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_settingupgerritverifyjobsforcastleuserprojects.summary.txt
# 📝 Saved summary: summaries\test-strategy_user-projects-cicd_suggestiononcrosstpllocaldireicorystructureformbtcastlehilandsilenvironments.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_08.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_doors-importer_developsubsidiarytoolfordoors-importer.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_doors-importer_exportingrequreiementsviadoorsimporter.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_doors-importer_linkingondoors.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_doors-importer_linkingondoorswhenimporteruiisnotlinkingwhileswtestspecmoduleisopen.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_its_intuitive-testing-suite-installation.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_its_tools.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_libgen_usinglibgenanda2lfilestosupportecucalibrationinc5basedsoftwaretestprojects.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_public-sessions.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestdesigner-1.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_cdvswoperationskpisbasedreviewmappingtoswtestsummary.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_plugin-system.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_plugin-system_ci-plugin.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_plugin-system_parkman-bluetooth-client-plugin.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_bl60swtestideticketsmapping.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_cdvswoperationskpisbasedreviewmappingtoswtestsummary.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_doorsxlsxexportstotsxmlconversion.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_gettingtestcoveragematrixintsxmlbasedprojects.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_gettingtestgroupticketvdrmappingintsxmlbasedprojects.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_requirementanalysisintsxmlbasedprojectusingtoolsbaseline66.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_swtestide461bl58includesnowfunctionalitytoreporttoolrelatedproblems.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_testgroupcommentfeatureinswtestide.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_tutorials-and-usecases.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_tutorials_unlockinggmailandgdriveinteraction-swtestide490.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_swtestide-1_virtual-pim-concept.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_tools-baseline-deployment.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_tsecg_tsecgmainresourcesproperties.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_tsecg_vw-application-test-file-comparator-tool.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_tutorials-and-usecases.summary.txt
# 📝 Saved summary: summaries\tools_additional-tools_user-guide.summary.txt
# 📝 Saved summary: summaries\tools_castle-system-driver.summary.txt
# 📝 Saved summary: summaries\tools_castle-system-driver_c-cre-client.summary.txt
# 📝 Saved summary: summaries\tools_castle-system-driver_lv-cre-client.summary.txt
# 📝 Saved summary: summaries\tools_cre_hardware-configuration_connecttospecificpiminrack2.summary.txt
# 📝 Saved summary: summaries\tools_cre_test-configuration_howtocreatetwolauncherfileseachwithspecificlibraries.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-command-line.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-command-line_cre-headless-mode.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-command-line_cre-local-utilities.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-embedded-mode.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-mastre-client.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-mastre-client_castle-configuration-in-mastre.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-mastre-client_supported-castle-commands-in-mastre.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-messaging-apis.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-path-support-test-context.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_cre-remote-java-client.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_enhanced-test-features.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_runtime-signal.summary.txt
# 📝 Saved summary: summaries\tools_cre_toolchain_toolchain-structure-castle-users.summary.txt
# 📝 Saved summary: summaries\tools_cre_troubleshooting_cannotconnecttorackmanagerafter3tries.summary.txt
# 📝 Saved summary: summaries\tools_cre_troubleshooting_castle-6-fw-dlt.summary.txt
# 📝 Saved summary: summaries\tools_cre_troubleshooting_fixobjectpathshortening.summary.txt
# 📝 Saved summary: summaries\tools_cte-control.summary.txt
# 📝 Saved summary: summaries\tools_cte_application-configurator_troubleshooting_arxml-integration-issue.summary.txt
# 📝 Saved summary: summaries\tools_cte_application-configurator_troubleshooting_dbc-integration-issues.summary.txt
# 📝 Saved summary: summaries\tools_cte_application-configurator_tutorials_add-multi-pim-solution-via-ui-configurator.summary.txt
# 📝 Saved summary: summaries\tools_cte_application-configurator_tutorials_dynamic-configuration-ui.summary.txt
# 📝 Saved summary: summaries\tools_cte_interfacing_wrongserverpasswordclaimatclientloginofcastleeolftmenu.summary.txt
# 📝 Saved summary: summaries\tools_cte_troubleshooting_cteapisnotresponding.summary.txt
# 📝 Saved summary: summaries\tools_cte_troubleshooting_cteprojectconnectionfailed.summary.txt
# 📝 Saved summary: summaries\tools_cte_troubleshooting_cterelease214-complainsaboutspectextsarenotunique.summary.txt
# 📝 Saved summary: summaries\tools_cte_troubleshooting_fixingcteloginfault10.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_add-startup-code-before-castle-launch.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_castle5-cte-runningexecutingaloop.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_cte-3-0-0.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_newfeatureenqueuetest.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_reloadaddons.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_reloadcte.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_signal-plotter.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_tsxml-starter-plugin.summary.txt
# 📝 Saved summary: summaries\tools_cte_tutorials_user-guide-cte.summary.txt
# 📝 Saved summary: summaries\tools_deployment.summary.txt
# 📝 Saved summary: summaries\tools_deployment_valeo-extern.summary.txt
# 📝 Saved summary: summaries\tools_deployment_valeo-intern.summary.txt
# 📝 Saved summary: summaries\tools_external-tools-interfacing_canoe_cre-canoe-client.summary.txt
# 📝 Saved summary: summaries\tools_external-tools-interfacing_robot-operating-system-ros_ros-delay-analysis.summary.txt
# 📝 Saved summary: summaries\tools_external-tools-interfacing_robot-operating-system-ros_ros-jade.summary.txt
# 📝 Saved summary: summaries\tools_external-tools-interfacing_vosstrex_vostrex.summary.txt
# 📝 Saved summary: summaries\tools_pc-setup_offline-machines_castle-project-packaging.summary.txt
# 📝 Saved summary: summaries\tools_pc-setup_offline-machines_convert-project-to-run-on-offline-machine.summary.txt
# 📝 Saved summary: summaries\tools_pc-setup_tutorials_castle5-project-initializer.summary.txt
# 📝 Saved summary: summaries\tools_pc-setup_tutorials_mcafeefirewallblockscastlecommunication-ifexecptionruleisnotdeployed.summary.txt
# 📝 Saved summary: summaries\tools_pc-setup_tutorials_rack-sharing-installation.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_adtf_adtf-datexporter-video.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_adtf_dvscastle-adtftool.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_adtf_extractasciifromdatusingadtf.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_beyond-compare_beyondcomparespeedfoldercomparisontip.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_dlt-viewer.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_doors_applyfilteronrequirementmodule.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_doors_doorslinkingnotworking.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_doors_exportingrequirementmodulefromdoorsserver.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipseautocompleteissue.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipsegitandlabeldecoration.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipseoxygen.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipseoxygen2.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipsepluginpapyrusforuml.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipseplugins.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_eclipseworkspacecorruption.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_fixingcrashedworkspaceineclipse4x.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_formatjavacodeandaddjavadoc.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_gerritconfigurationineclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_howtorevertcodefromlocalhistoryusingeclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_introductiontocorealmusinggitperspectiveineclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_oldjavaprojectscantbebuiltwithneweclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_removebuildconfigurationfromeclipsesdk.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_runantscriptineclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_eclipse_viewxmlfromeclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_emacs_emacstexteditorforwindows.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_ethernet-utility_fastpingingusingtping.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_avoidopeningchangeswhicharerelatedtoeachotherifthereisnoneedforthisrelation.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_badpracticestoavoidwhenusinggerrit.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_c5-project-versioning.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_cachingcredentialsforgitlfs.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_cloningsymboliclinkssymlinksfromgitonwindows.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_comparinggitbrancheswithyourcomparingtool.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_dealinginthemostsimplestwaywithgitincastleuserprojectsusecases.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_fetchinglargefilesfromcorealmprojectsusinggitlfs.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_fixgitlfsfiles.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_generate-gerrit-change-id.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gerritmarkyourchangeaswork-in-progress.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gerrituploadyourcommitasdraft.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-add-hunks-of-file.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-bundle.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_Git-Commit.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-create-multiple-copies-of-your-project-git-work-trees.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-hooks.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-how-to-retrieve-any-file-from-a-specific-commit-manually.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-import-and-filtering.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-most-common-issues-for-castle-users.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git-submodules.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_git.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitbashwrapslineincorruptedway.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitcherry-pickacommitfromanothergitrepository.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitclistageallmodifiedanddeletedfilesbutnotnewones.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitcommentswithchangeids-howtheyshouldlooklike-andwhattheyshouldcontain.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_githaveaversionedconfig.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_githowtotrackdirectoriesbutnottheirfileswithgit.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitlfsobjectoidnotfound.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitmergetwocommits.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitmigration-authornamechanging.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitproblemswithlongpathnames.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitpullbestpractice.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitrebasebranchontoanotherbranch.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitrecoveryfromhardreset.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitshowhistoryforspecificfile.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_gitwhatsadetachedheadingit.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_hot-to-stage-multiple-test-items-tsxml-tsres-c5r-and-lfs-push-via-git-bash.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_mergingbranchesusinggitmergtool.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_nonlinearhistoryingitprojects.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_rebasingingerritandgitandcherry-pick.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_restoringdeletedbranchescommits.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_reviewadditionofbinaryfilestogit.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_usedebuginfowithgitcommands.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_git_user-project-using-git.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_google-workspace_cloud-search_usinggooglecloudsearchasyourdefaultchromesearchengine.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_google-workspace_drive_howtouploadlargesizefilesongdriveovernight.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_google-workspace_gmail_listingarchivedemailsingmail.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_google-workspace_sheets_googlesheetsconcatenatecellswithnewline.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_go_goprogramminglanguage.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_gradle_gradle-daemon-timeout.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_gradle_gradletaskalwaysup-to-date.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_hex-editor_ausefulhexeditorwxhexeditor.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_hex-editor_handy-hex-editor-viewer.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_addinglocksandsynchronizedmethodsinjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_assertionsinjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_briefintroonjavanativeinterfacejni.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_convertintegertohexstringwithcertainnumberofdigitsinjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_exportmainclasstoexecutablejarineclipse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_isjavapass-by-referenceorpass-by-value.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_java-shutdown-hook.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javaoophints.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javaunittestcodecoverage.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javaunittesting-asserts.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javaverygoodlearningcourse.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javavirtualmachine.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_javawexevsjavaexe.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_jaxbxmljavaconvertion.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_jvm-monitoring.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_lambdaexpression.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_matchgroupsbynameinregularexpressioninjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_parseandeditxmlfilesinjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_runpythonpatchfromjavaprogram.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_runuiinanotherthreadjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_useful-java-conversions.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_java_usingstreamstoaddtexttoeachelementinsetofstringsjava.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_batchfilesandshellscripting.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_changeinfilescontentusingbash.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_copyerror-thefilenamewouldbetoolongforthedestinationfolder.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_debugmissinglibsoonlinuxusinglddcommand.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_gitdifffilesinmeld.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_inotify.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_linuxlistrecursivelywithabsolutepath.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_netcatasasimplewebserver.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_linux-os_removetrailingwhitespaces.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_logic-analyzer_logicanalyzerusbee.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_notepad_commentsinnotepad.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_notepad_notepadeditmenu.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_arxml-editor_howtoeditarxmlfile.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_automatedcanframecyclictimetestusingcapl.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_canalyzer-ig.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_canoeastcpserver.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_canoeconfigurationforethernetcaplcode.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_canoeconfigurecanoeasapassivecannode.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_canoelinconfigurelinmasterigincanoe.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_communicationwithcanoe.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_genericethernetcaplcode.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_lin20-canoe-masterresistor.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_sendcyclicethernetpacketipv4ipv6usingcaplcode.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_simulate-ethernet-nodes-in-arxml.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_canoe_splitting-canoe-trace-by-time.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_vector_dbc_addingsignaltodbc.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_compilepythonscriptstostandalonewindowsexecutableexe.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_dlldependencies.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_fix-telnet-scrolling-issue-in-windows-terminal-wt.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_powershellscriptforpcperformancemonitoring.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_remotedesktopconnectionfullscreen.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_remotely-control-powersupply.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_set-windows-user-environment-variable-permanently-with-powershell.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_staticvsdynamicpythonscriptcompilingintoexecutableexefile.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_windows-os_suppresswindowsterminaltitleupdates.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_wireshark_defineethernetdataprotocolforwireshark.summary.txt
# 📝 Saved summary: summaries\tools_third-party-tools_wireshark_wiresharkdissector.summary.txt

# %%
import os
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

api_pages_folder = "api_pages"
api_summaries_folder = "api_summaries"
os.makedirs(api_summaries_folder, exist_ok=True)

# Load docs from pages folder
api_docs = []
for filename in os.listdir(api_pages_folder):
    if filename.endswith(".md"):
        filepath = os.path.join(api_pages_folder, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            content = f.read().strip()
        if content:
            api_docs.append(Document(page_content=content, metadata={"source": filename}))

print(f"✅ Loaded {len(api_docs)} documents from {api_pages_folder}")

# Define chain
chain = (
    {"doc": lambda x: x.page_content, "name": lambda x: x.metadata["source"]}
    | ChatPromptTemplate.from_template(
        "You are summarizing a document extracted from a file.\n\n"
        "File Name: {name}\n\n"
        "Document Content:\n{doc}\n\n"
        "Please provide a clear, concise summary."
    )
    | ChatOpenAI(model="gpt-3.5-turbo", max_retries=0)
    | StrOutputParser()
)

# Run summarization
api_summaries = chain.batch(api_docs, {"max_concurrency": 5})

# Save each summary
for doc, summary in zip(api_docs, api_summaries):
    filename = doc.metadata["source"]
    summary_filename = filename.replace(".md", ".summary.txt")
    summary_path = os.path.join(api_summaries_folder, summary_filename)
    with open(summary_path, "w", encoding="utf-8") as f:
        f.write(f"Source File: {filename}\n\nSummary:\n{summary}")
    print(f"📝 Saved summary: {summary_path}")
# Out:
# ✅ Loaded 240 documents from api_pages
# 📝 Saved summary: api_summaries\AdcControl.summary.txt
# 📝 Saved summary: api_summaries\AkSensors.summary.txt
# 📝 Saved summary: api_summaries\AngleDataSync.summary.txt
# 📝 Saved summary: api_summaries\Backlight_Feature.summary.txt
# 📝 Saved summary: api_summaries\Bap.summary.txt
# 📝 Saved summary: api_summaries\Base6Io.summary.txt
# 📝 Saved summary: api_summaries\BaseIo.summary.txt
# 📝 Saved summary: api_summaries\BaseSensors.summary.txt
# 📝 Saved summary: api_summaries\BipIo.summary.txt
# 📝 Saved summary: api_summaries\Calibrate.summary.txt
# 📝 Saved summary: api_summaries\CanBap.summary.txt
# 📝 Saved summary: api_summaries\CanDiag.summary.txt
# 📝 Saved summary: api_summaries\CanDiagSlave.summary.txt
# 📝 Saved summary: api_summaries\CanDriver.summary.txt
# 📝 Saved summary: api_summaries\CanXcp.summary.txt
# 📝 Saved summary: api_summaries\Clamp.summary.txt
# 📝 Saved summary: api_summaries\Climate.summary.txt
# 📝 Saved summary: api_summaries\ComLinSched_Tables.summary.txt
# 📝 Saved summary: api_summaries\ComPcEthernet.summary.txt
# 📝 Saved summary: api_summaries\ComPcEthernetPdus.summary.txt
# 📝 Saved summary: api_summaries\ComPcEthernetServiceInstances.summary.txt
# 📝 Saved summary: api_summaries\ComPcEthernetSignals.summary.txt
# 📝 Saved summary: api_summaries\CycleStats.summary.txt
# 📝 Saved summary: api_summaries\DataServer.summary.txt
# 📝 Saved summary: api_summaries\DataServerTest.summary.txt
# 📝 Saved summary: api_summaries\DelayedEvent.summary.txt
# 📝 Saved summary: api_summaries\Diag.summary.txt
# 📝 Saved summary: api_summaries\DiagSlave.summary.txt
# 📝 Saved summary: api_summaries\EdgeTrace.summary.txt
# 📝 Saved summary: api_summaries\EthernetBap.summary.txt
# 📝 Saved summary: api_summaries\EthernetDevice.summary.txt
# 📝 Saved summary: api_summaries\EthernetDoIP.summary.txt
# 📝 Saved summary: api_summaries\EthernetFilter.summary.txt
# 📝 Saved summary: api_summaries\EthernetHsfz.summary.txt
# 📝 Saved summary: api_summaries\EthernetIperf.summary.txt
# 📝 Saved summary: api_summaries\EthernetNetworkInterface.summary.txt
# 📝 Saved summary: api_summaries\EthernetServerSocket.summary.txt
# 📝 Saved summary: api_summaries\EthernetServerSocketConnection.summary.txt
# 📝 Saved summary: api_summaries\EthernetSocket.summary.txt
# 📝 Saved summary: api_summaries\EthernetXcp.summary.txt
# 📝 Saved summary: api_summaries\EventFilter.summary.txt
# 📝 Saved summary: api_summaries\FaultBox.summary.txt
# 📝 Saved summary: api_summaries\FcPipAnalogInChannel.summary.txt
# 📝 Saved summary: api_summaries\FcPipAnalogInputs.summary.txt
# 📝 Saved summary: api_summaries\FcPipAnalogOutChannel.summary.txt
# 📝 Saved summary: api_summaries\FcPipAnalogOuts.summary.txt
# 📝 Saved summary: api_summaries\FcPipDigitalInputChannel.summary.txt
# 📝 Saved summary: api_summaries\FcPipDigitalInputs.summary.txt
# 📝 Saved summary: api_summaries\FcPipDigitalOuts.summary.txt
# 📝 Saved summary: api_summaries\FcPipIo.summary.txt
# 📝 Saved summary: api_summaries\FirmwareTracer.summary.txt
# 📝 Saved summary: api_summaries\FlexrayBap.summary.txt
# 📝 Saved summary: api_summaries\FlexrayDiag.summary.txt
# 📝 Saved summary: api_summaries\FlexrayDriver.summary.txt
# 📝 Saved summary: api_summaries\FlexrayXcp.summary.txt
# 📝 Saved summary: api_summaries\GenCloneable.summary.txt
# 📝 Saved summary: api_summaries\Generic.summary.txt
# 📝 Saved summary: api_summaries\GenericC6.summary.txt
# 📝 Saved summary: api_summaries\GenericC6Apu.summary.txt
# 📝 Saved summary: api_summaries\GenericCommon.summary.txt
# 📝 Saved summary: api_summaries\GenericDriver.summary.txt
# 📝 Saved summary: api_summaries\Hod.summary.txt
# 📝 Saved summary: api_summaries\HpGeneric.summary.txt
# 📝 Saved summary: api_summaries\HpSensors.summary.txt
# 📝 Saved summary: api_summaries\IicSlaveHw.summary.txt
# 📝 Saved summary: api_summaries\Iperf3.summary.txt
# 📝 Saved summary: api_summaries\LCD_TFT_Unit.summary.txt
# 📝 Saved summary: api_summaries\Led.summary.txt
# 📝 Saved summary: api_summaries\Leds.summary.txt
# 📝 Saved summary: api_summaries\LinDiag.summary.txt
# 📝 Saved summary: api_summaries\LinDriver.summary.txt
# 📝 Saved summary: api_summaries\LinGeneric.summary.txt
# 📝 Saved summary: api_summaries\LinMaster.summary.txt
# 📝 Saved summary: api_summaries\LinSlave.summary.txt
# 📝 Saved summary: api_summaries\Logic_Control.summary.txt
# 📝 Saved summary: api_summaries\MEU.summary.txt
# 📝 Saved summary: api_summaries\MIPC.summary.txt
# 📝 Saved summary: api_summaries\PerformanceMonitor.summary.txt
# 📝 Saved summary: api_summaries\Ping.summary.txt
# 📝 Saved summary: api_summaries\PipIo_DIn.summary.txt
# 📝 Saved summary: api_summaries\PipRad.summary.txt
# 📝 Saved summary: api_summaries\PipRadIo.summary.txt
# 📝 Saved summary: api_summaries\PipRadV6.summary.txt
# 📝 Saved summary: api_summaries\PipRlt.summary.txt
# 📝 Saved summary: api_summaries\PowerSupply.summary.txt
# 📝 Saved summary: api_summaries\PowerSupplyChannel.summary.txt
# 📝 Saved summary: api_summaries\PsIic.summary.txt
# 📝 Saved summary: api_summaries\PTP.summary.txt
# 📝 Saved summary: api_summaries\PWM.summary.txt
# 📝 Saved summary: api_summaries\PwmGenerator.summary.txt
# 📝 Saved summary: api_summaries\RAD_ADC.summary.txt
# 📝 Saved summary: api_summaries\RAD_CAN.summary.txt
# 📝 Saved summary: api_summaries\RAD_CS.summary.txt
# 📝 Saved summary: api_summaries\RAD_DAC.summary.txt
# 📝 Saved summary: api_summaries\RAD_DIO.summary.txt
# 📝 Saved summary: api_summaries\RAD_HMI.summary.txt
# 📝 Saved summary: api_summaries\RAD_PSM.summary.txt
# 📝 Saved summary: api_summaries\RAD_UART.summary.txt
# 📝 Saved summary: api_summaries\RLT_ADC.summary.txt
# 📝 Saved summary: api_summaries\RLT_DAC.summary.txt
# 📝 Saved summary: api_summaries\RLT_Gpio.summary.txt
# 📝 Saved summary: api_summaries\RLT_I2c.summary.txt
# 📝 Saved summary: api_summaries\Rs232.summary.txt
# 📝 Saved summary: api_summaries\SelfTest.summary.txt
# 📝 Saved summary: api_summaries\SensorsMux.summary.txt
# 📝 Saved summary: api_summaries\SMOSLoadSwitch.summary.txt
# 📝 Saved summary: api_summaries\Speaker.summary.txt
# 📝 Saved summary: api_summaries\SpeakerAndMic.summary.txt
# 📝 Saved summary: api_summaries\StepperMotor.summary.txt
# 📝 Saved summary: api_summaries\StopWatch.summary.txt
# 📝 Saved summary: api_summaries\Switches.summary.txt
# 📝 Saved summary: api_summaries\Switches_i.summary.txt
# 📝 Saved summary: api_summaries\SwsRoller.summary.txt
# 📝 Saved summary: api_summaries\SystemInfo.summary.txt
# 📝 Saved summary: api_summaries\TcmPip.summary.txt
# 📝 Saved summary: api_summaries\TCM_Dio.summary.txt
# 📝 Saved summary: api_summaries\TCM_DioGroup.summary.txt
# 📝 Saved summary: api_summaries\TCM_DioGroups.summary.txt
# 📝 Saved summary: api_summaries\TCM_GeneralAdc.summary.txt
# 📝 Saved summary: api_summaries\TCM_GeneralAdcs.summary.txt
# 📝 Saved summary: api_summaries\TCM_GeneralDac.summary.txt
# 📝 Saved summary: api_summaries\TCM_GeneralDacs.summary.txt
# 📝 Saved summary: api_summaries\TCM_LeverSim.summary.txt
# 📝 Saved summary: api_summaries\TCM_LeverSimGroup.summary.txt
# 📝 Saved summary: api_summaries\TCM_LeverSimGroups.summary.txt
# 📝 Saved summary: api_summaries\TCM_Plug_Line.summary.txt
# 📝 Saved summary: api_summaries\TCM_Plug_Lines.summary.txt
# 📝 Saved summary: api_summaries\TCM_ReadbackAdc6.summary.txt
# 📝 Saved summary: api_summaries\TCM_SasDac.summary.txt
# 📝 Saved summary: api_summaries\TCM_SasDacs.summary.txt
# 📝 Saved summary: api_summaries\TCM_Signals_Monitoring.summary.txt
# 📝 Saved summary: api_summaries\TCU_ADC.summary.txt
# 📝 Saved summary: api_summaries\TCU_ADC_LowSpeed.summary.txt
# 📝 Saved summary: api_summaries\TCU_DAC.summary.txt
# 📝 Saved summary: api_summaries\TCU_DIO.summary.txt
# 📝 Saved summary: api_summaries\TCU_LIN.summary.txt
# 📝 Saved summary: api_summaries\TCU_MIC.summary.txt
# 📝 Saved summary: api_summaries\TCU_PG.summary.txt
# 📝 Saved summary: api_summaries\TCU_SPE.summary.txt
# 📝 Saved summary: api_summaries\TCU_SPK.summary.txt
# 📝 Saved summary: api_summaries\TCU_SUP.summary.txt
# 📝 Saved summary: api_summaries\TCU_Switches.summary.txt
# 📝 Saved summary: api_summaries\TCU_UART.summary.txt
# 📝 Saved summary: api_summaries\TestData.summary.txt
# 📝 Saved summary: api_summaries\Timer.summary.txt
# 📝 Saved summary: api_summaries\ToeDriver.summary.txt
# 📝 Saved summary: api_summaries\Tracer.summary.txt
# 📝 Saved summary: api_summaries\TriggerInput.summary.txt
# 📝 Saved summary: api_summaries\UpaPcCanCom.summary.txt
# 📝 Saved summary: api_summaries\USV10.summary.txt
# 📝 Saved summary: api_summaries\USV10_Switches.summary.txt
# 📝 Saved summary: api_summaries\UsvBaseSensors.summary.txt
# 📝 Saved summary: api_summaries\VideoProcessorUnit.summary.txt
# 📝 Saved summary: api_summaries\VlsPipAnalogOutChannel.summary.txt
# 📝 Saved summary: api_summaries\VlsPipAnalogOuts.summary.txt
# 📝 Saved summary: api_summaries\VlsPipDigitalInputChannel.summary.txt
# 📝 Saved summary: api_summaries\VlsPipDigitalInputs.summary.txt
# 📝 Saved summary: api_summaries\VlsPipDigitalOuts.summary.txt
# 📝 Saved summary: api_summaries\VlsPipIo.summary.txt
# 📝 Saved summary: api_summaries\VlsPipLoadLine.summary.txt
# 📝 Saved summary: api_summaries\VlsPipLoadLines.summary.txt
# 📝 Saved summary: api_summaries\VlsPipPowerSupplyOut.summary.txt
# 📝 Saved summary: api_summaries\VlsPowerSupplyOuts.summary.txt
# 📝 Saved summary: api_summaries\WaveGenOutput.summary.txt
# 📝 Saved summary: api_summaries\WheelTicks.summary.txt
# 📝 Saved summary: api_summaries\XCP.summary.txt
# 📝 Saved summary: api_summaries\ZcAnalogInChannel.summary.txt
# 📝 Saved summary: api_summaries\ZcAnalogInputs.summary.txt
# 📝 Saved summary: api_summaries\ZcAnalogOuts.summary.txt
# 📝 Saved summary: api_summaries\ZcDigitalOuts.summary.txt
# 📝 Saved summary: api_summaries\ZcDInPwm.summary.txt
# 📝 Saved summary: api_summaries\ZcFaultBoxs.summary.txt
# 📝 Saved summary: api_summaries\ZcLoadSwitchs.summary.txt
# 📝 Saved summary: api_summaries\ZcPipDigitalInputs.summary.txt
# 📝 Saved summary: api_summaries\ZcPipIo.summary.txt
# 📝 Saved summary: api_summaries\ZC_DIO_OC_PU_CH.summary.txt
# 📝 Saved summary: api_summaries\Zc_DIO_OC_PU_CHS.summary.txt
# 📝 Saved summary: api_summaries\_Com.summary.txt
# 📝 Saved summary: api_summaries\_ComBrStructEthernetSpecificRx.summary.txt
# 📝 Saved summary: api_summaries\_ComBrStructEthernetSpecificTx.summary.txt
# 📝 Saved summary: api_summaries\_ComCan.summary.txt
# 📝 Saved summary: api_summaries\_ComDataMessagePublisher.summary.txt
# 📝 Saved summary: api_summaries\_ComDataMessageSubscriber.summary.txt
# 📝 Saved summary: api_summaries\_ComEthernet.summary.txt
# 📝 Saved summary: api_summaries\_ComEthernetSpecific.summary.txt
# 📝 Saved summary: api_summaries\_ComFlexray.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanMux.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanMuxRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanMuxRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanMuxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameCanTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameDynamicFlexrayRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameDynamicFlexrayTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameEthernetSpecificRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameEthernetSpecificRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameEthernetSpecificTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameFlexrayRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameFlexrayTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGenericRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGenericRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGenericTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGmExtendedCan.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGmExtendedCanRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameGmExtendedCanTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameLin.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameLinRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameLinTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameRx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameStaticFlexrayRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComFrameStaticFlexrayTx.summary.txt
# 📝 Saved summary: api_summaries\_ComGeneric.summary.txt
# 📝 Saved summary: api_summaries\_ComLin.summary.txt
# 📝 Saved summary: api_summaries\_ComMethodClient.summary.txt
# 📝 Saved summary: api_summaries\_ComMethodServer.summary.txt
# 📝 Saved summary: api_summaries\_ComPduCanRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduCanRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduCanTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduEthernetRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduEthernetTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduFlexrayRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduFlexrayRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduFlexrayTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduGenericRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduGenericRxTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduGenericTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduLinRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduLinTx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduRx.summary.txt
# 📝 Saved summary: api_summaries\_ComPduSecured.summary.txt
# 📝 Saved summary: api_summaries\_ComPduTx.summary.txt
# 📝 Saved summary: api_summaries\_ComSDClientService.summary.txt
# 📝 Saved summary: api_summaries\_ComSDConsumedEventGroup.summary.txt
# 📝 Saved summary: api_summaries\_ComSDProvidedEventGroup.summary.txt
# 📝 Saved summary: api_summaries\_ComSDServerService.summary.txt
# 📝 Saved summary: api_summaries\_Signal.summary.txt
# 📝 Saved summary: api_summaries\_SignalImpl.summary.txt
# 📝 Saved summary: api_summaries\_SignalRaw.summary.txt
# 📝 Saved summary: api_summaries\_SignalValue.summary.txt

# %%
import os
import uuid
from langchain_core.documents import Document
from langchain.storage import LocalFileStore
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers.multi_vector import MultiVectorRetriever


persist_dir = "chroma_db"
store_dir = "doc_store"

# Shared vectorstore + storage
vectorstore = Chroma(
    collection_name="summaries",
    embedding_function=OpenAIEmbeddings(),
    persist_directory=persist_dir,
)
store = LocalFileStore(store_dir)
id_key = "doc_id"

retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    byte_store=store,
    id_key=id_key,
)


def add_docs_to_store(docs, summaries, source_type: str):
    """
    Add a batch of documents + summaries to Chroma and LocalFileStore.

    Args:
        docs (list[Document]): Full documents
        summaries (list[str]): Summaries corresponding to docs
        source_type (str): Tag to distinguish ("api_summary", "wiki_summary", etc.)
    """
    # Stable IDs: use filename if available, else uuid
    doc_ids = [
        docs[i].metadata.get("source", str(uuid.uuid4()))
        for i in range(len(docs))
    ]

    # Build summary docs with metadata
    summary_docs = [
        Document(
            page_content=summaries[i],
            metadata={
                id_key: doc_ids[i],
                "source": docs[i].metadata.get("source", "unknown"),
                "source_type": source_type,
            },
        )
        for i in range(len(docs))
    ]

    # Add to vectorstore
    retriever.vectorstore.add_documents(summary_docs)

    # Store original docs
    retriever.docstore.mset(list(zip(doc_ids, docs)))

    # Persist changes
    vectorstore.persist()

    print(f"✅ Added {len(docs)} docs with source_type='{source_type}'")


# Example usage:
add_docs_to_store(docs, summaries, "api_summary")
add_docs_to_store(api_docs, api_summaries, "wiki_summary")
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_25192\479125494.py:14: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_25192\479125494.py:64: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()
# ✅ Added 541 docs with source_type='api_summary'
# ✅ Added 240 docs with source_type='wiki_summary'

# %%
retriever_all = vectorstore.as_retriever(
    search_kwargs={"k": 5}
)


retriever_api = vectorstore.as_retriever(
    search_kwargs={"k": 1, "filter": {"source_type": "wiki_summary"}}
)

# ✅ Wiki-only retriever
retriever_wiki = vectorstore.as_retriever(
    search_kwargs={"k": 1, "filter": {"source_type": "api_summary"}}
)

# %%
results = retriever_api.invoke("_ComFlexray")
print(results[0].metadata)
# Out:
# {'source': 'FlexrayDiag.md', 'source_type': 'wiki_summary', 'doc_id': 'FlexrayDiag.md'}

# %%
# Let's say you got some results from retriever
results = retriever_api.invoke("flexray")

# Each result is a summary Document
summary_docawy = results[0]
print("Summary:", summary_docawy.page_content)
print("Metadata:", summary_docawy.metadata)

# Now fetch the full/original doc from store using the doc_id
doc_id = summary_docawy.metadata["doc_id"]
original_doc = retriever.docstore.mget([doc_id])[0]

print("✅ Original doc content:")
print(original_doc.page_content)
print("✅ Original doc metadata:")
print(original_doc.metadata)
# Out:
# Summary: The document outlines various functions and their descriptions related to Flexray Diagnosis, including calculating access keys, configuring timeouts, sending requests cyclically, modifying requests, and testing byte sequences. It also includes messages related to error handling and response verification.
# Metadata: {'doc_id': 'FlexrayDiag.md', 'source': 'FlexrayDiag.md', 'source_type': 'wiki_summary'}
# ✅ Original doc content:
# ### Function: CalculateAccessKey
#
# **Description:** Description: Purpose: Calculate a security access key based on a seed and other parameters. Example: *_ApiCalculateAccessKey(4, 4, 2, 2, 0x01, [0xDE, 0xAD, 0xBE, 0xEF]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Default |
# |---|---|---|---|
# | SeedSize | int | uint32 |  |
# | The seed size in bytes |  |  |  |
# | KeySize | int | uint32 |  |
# | The key size in bytes |  |  |  |
# | SeedOffset | int | uint32 |  |
# | The seed offset in diag response buffer |  |  |  |
# | KeyOffset | int | uint32 |  |
# | The key offset in diag request buffer |  |  |  |
# | SecurityLevel | int | uint8 |  |
# | Security Level Number |  |  |  |
# | StaticKey | int[] | uint8 | [] |
# | To Decrypt/Encrypt Seed/Key (e.g. In AES128 Algo). Leave it empty if not needed |  |  |  |
#
#
# ---
#
# ### Function: ConfigureDefaultTimeout
#
# **Description:** Description: Purpose: Configure default timeout for all send actions. Example: *_ApiConfigureDefaultTimeout(1000, 5000) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | Timeout | int | uint16 | ms |
# | Timeout --> P2server in ISO doc: the maximum time to wait between a diag request and any response received after it i,e; positive , negative or, pending response. |  |  |  |
# | PendingResponseTimeout | int | uint16 | ms |
# | PendingResponseTimeout--> P2*server in ISO doc: the maximum time to wait between a pending response and any response received after it i,e; positive , negative or, pending response |  |  |  |
#
#
# ---
#
# ### Function: ConfigureDiag
#
# **Description:** Description: Purpose: Configure Diag Module: Enable/Disable Tp. Example: *_ApiConfigureDiag(true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | EnableTp | boolean | bool |
# | If true, enables the Transport Protocol (TP) layer for diagnostics; if false, disables it. |  |  |
#
#
# ---
#
# ### Function: ConfigureFlowControlSendStMin
#
# **Description:** Description: Purpose: Configure CASTLE to overwrite STMin value received from the ECU in Flow Control Frame Example: *_ApiConfigureFlowControlSendStMin(10, UserInput) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | FcSendStMin | int | uint8 | ms |
# | The flow control send StMin (in ms). |  |  |  |
# | SendStMinMode | SendStMinMode | int | - |
# | The mode for sending StMin. |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_DisableTimeout
#
# **Description:** Description: Purpose: Configure disabling the timeout for the next send action. Example: *_ApiConfigureNextSend_DisableTimeout()
#
#
# ---
#
# ### Function: ConfigureNextSend_FirstConsecutiveDelay
#
# **Description:** Description: Purpose: Configure Castle first consecutive frame with a user defined delay time measured from the Ecu flow control signal. Example: *_ApiConfigureNextSend_FirstConsecutiveDelay(5) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | CfDelay | int | uint8 | ms |
# | The consecutive frame delay (in ms). |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_FlowControlData
#
# **Description:** Description: Purpose: Configure Castle next flow control frame data : receive block size and receive StMin. Example: *_ApiConfigureNextSend_FlowControlData(8, 10) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | FcRecvBlockSize | int | uint8 |  |
# | The flow control receive block size. |  |  |  |
# | FcRecvStMin | int | uint8 | ms |
# | The flow control receive StMin (in ms). |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_FlowControlDelay
#
# **Description:** Description: Purpose: Configure Castle flow control signal with a user defined delay time measured from the Ecu first frame. Example: *_ApiConfigureNextSend_FlowControlDelay(10) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | FcDelay | int | uint16 | ms |
# | The flow control delay (in ms). |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_Response
#
# **Description:** Description: Purpose: Configure what is expected as response. Example: *_ApiConfigureNextSend_Response(true, false, true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | SuppressNegRsp | boolean | bool |
# | If true, negative responses will be suppressed. |  |  |
# | SuppressPosRsp | boolean | bool |
# | If true, positive responses will be suppressed. |  |  |
# | AllowResponsePending | boolean | bool |
# | If true, response pending is allowed. |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_Retries
#
# **Description:** Description: Purpose: Configure options for automatic retry in the case where "busy repeat" was the response from ECU. Example: *_ApiConfigureNextSend_Retries(3, 10) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Scale | Unit |
# |---|---|---|---|---|
# | Retries | int | uint8 |  |  |
# | The number of retries to perform. |  |  |  |  |
# | PauseTime | int | uint16 | 0.2 | ms |
# | The pause time between retries (in ms). |  |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_Timeout
#
# **Description:** Description: Purpose: Configure next timeout for all send actions Example: *_ApiConfigureNextSend_Timeout(1000, 5000) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Unit |
# |---|---|---|---|
# | Timeout | int | uint16 | ms |
# | Timeout --> P2server in ISO doc: the maximum time to wait between a diag request and any response received after it i,e; positive , negative or, pending response. |  |  |  |
# | PendingResponseTimeout | int | uint16 | ms |
# | PendingResponseTimeout--> P2*server in ISO doc: the maximum time to wait between a pending response and any response received after it i,e; positive , negative or, pending response |  |  |  |
#
#
# ---
#
# ### Function: ConfigureNextSend_Type
#
# **Description:** Description: Purpose: Send a diagnostic request. If a response is received, store it in the internal buffer and generate a logging message Example: *_ApiConfigureNextSend_Type(true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | AsFunctional | boolean | bool |
# | If true, the request will be sent as a functional request. If false, it will be sent as a physical request. |  |  |
#
#
# ---
#
# ### Function: ConfigureUnexpectedReceive
#
# **Description:** Description: Purpose: Configure disabling/enabling the unexpected receive if no send action was made. Example: *_ApiConfigureUnexpectedReceive(true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | AllowUnexpectedReceiveWarning | boolean | bool |
# | If true, unexpected receive warning is allowed. |  |  |
#
#
# ---
#
# ### Function: Configure_OnTestResponseFailedLogResponseAsError
#
# **Description:** Description: Purpose: When enabled, and TestResponse fails, the response will be logged as an error. Example: *_ApiConfigure_OnTestResponseFailedLogResponseAsError(true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Enable | boolean | bool |
# | Enable or disable logging the response as an error when TestResponse fails. |  |  |
#
#
# ---
#
# ### Function: CopyRequestBitsToProcUnitVariable
#
# **Description:** Description: Purpose: Copy a bit sequence from the current request to a variable in the procunit. Example: *_ApiCopyRequestBitsToProcUnitVariable(2, 4, 8, false, true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable to copy the request bits to. |  |  |
# | StartBit | int | uint16 |
# | The starting bit position in the current request data from which to copy. |  |  |
# | BitLength | int | uint16 |
# | The number of bits to copy from the request data. |  |  |
# | ByteOrderBigEndian | boolean | bool |
# | Specifies the byte order (true for big-endian, false for little-endian) for interpreting the bits. |  |  |
# | AsSignedValue | boolean | bool |
# | Specifies if the copied bits should be interpreted as a signed value (true) or unsigned (false). |  |  |
#
#
# ---
#
# ### Function: CopyRequestLengthToProcUnitVariable
#
# **Description:** Description: Purpose: Copy the length of the current request to a variable in the procunit. Example: *_ApiCopyRequestLengthToProcUnitVariable(2) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable where the current request length will be copied. |  |  |
#
#
# ---
#
# ### Function: CopyRequestToProcUnitVariable
#
# **Description:** Description: Purpose: Copy a part of the current request to a variable in the procunit. Example: *_ApiCopyRequestToProcUnitVariable(2, 1, 3, false) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable to copy the request data to. |  |  |
# | Offset | int | uint8 |
# | The starting offset in the current request data from which to copy. |  |  |
# | ByteLength | int | uint8 |
# | The number of bytes to copy from the request data. |  |  |
# | BigEndian | boolean | bool |
# | Specifies if the copied data should be interpreted as big-endian (true) or little-endian (false). |  |  |
#
#
# ---
#
# ### Function: CopyResponseBitsToProcUnitVariable
#
# **Description:** Description: Purpose: Copy a bit sequence from the last received response to a variable in the procunit. Example: *_ApiCopyResponseBitsToProcUnitVariable(1, 8, 16, true, false) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable to copy the response bits to. |  |  |
# | StartBit | int | uint16 |
# | The starting bit position in the received response data from which to copy. |  |  |
# | BitLength | int | uint16 |
# | The number of bits to copy from the response data. |  |  |
# | ByteOrderBigEndian | boolean | bool |
# | Specifies the byte order (true for big-endian, false for little-endian) for interpreting the bits. |  |  |
# | AsSignedValue | boolean | bool |
# | Specifies if the copied bits should be interpreted as a signed value (true) or unsigned (false). |  |  |
#
#
# ---
#
# ### Function: CopyResponseLengthToProcUnitVariable
#
# **Description:** Description: Purpose: Copy the length of the last received response to a variable in the procunit. Example: *_ApiCopyResponseLengthToProcUnitVariable(1) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable where the response length will be copied. |  |  |
#
#
# ---
#
# ### Function: CopyResponseToProcUnitVariable
#
# **Description:** Description: Purpose: Copy a part of the last received response to a variable in the procunit. Example: *_ApiCopyResponseToProcUnitVariable(1, 2, 4, true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the proc unit variable to copy the response data to. |  |  |
# | Offset | int | uint8 |
# | The starting offset in the received response data from which to copy. |  |  |
# | ByteLength | int | uint8 |
# | The number of bytes to copy from the response data. |  |  |
# | BigEndian | boolean | bool |
# | Specifies if the copied data should be interpreted as big-endian (true) or little-endian (false). |  |  |
#
#
# ---
#
# ### Function: EnablePadding
#
# **Description:** Description: Purpose: Enable or disable padding for diagnostic messages. Padding is enabled by default. Example: *_ApiEnablePadding(false) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Enable | boolean | bool |
# | If true, enables padding for diagnostic messages; if false, disables padding. Padding is enabled by default. |  |  |
#
#
# ---
#
# ### Function: GetCyclicResponse
#
# **Description:** Description: Purpose: Gets the latest response received from a cyclically sent diagnostic request. Example: *_ApiGetCyclicResponse()
#
#
# ---
#
# ### Function: Prepare
#
# **Description:** Description: Purpose: Prepare the request to be send. Example: *_ApiPrepare([0x10, 0x03]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
# | The data to prepare for sending. |  |  |  |
#
#
# ---
#
# ### Function: PrepareFromResponse
#
# **Description:** Description: Purpose: Prepare the request to be send from the previously received response. Example: *_ApiPrepareFromResponse()
#
#
# ---
#
# ### Function: PrepareModify
#
# **Description:** Description: Purpose: Modify the prepared request by replacing a byte sequence. Example: *_ApiPrepareModify(2, [0x01, 0x02]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset where to replace the data. |  |  |  |
# | Data | int[] | uint8 | raw |
# | The data to replace with. |  |  |  |
#
#
# ---
#
# ### Function: PrepareModifyBits
#
# **Description:** Description: Purpose: Modify the prepared repuest by replacing a bit sequence. Example: *_ApiPrepareModifyBits(0x1234, 8, 16, true, false) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Value | long | int64 |
# | The value to set. |  |  |
# | StartBit | int | uint16 |
# | The start bit position. |  |  |
# | BitLength | int | uint16 |
# | The length of the bit sequence. |  |  |
# | ByteOrderBigEndian | boolean | bool |
# | If true, use big-endian byte order. |  |  |
# | AsSignedValue | boolean | bool |
# | If true, interpret the value as signed. |  |  |
#
#
# ---
#
# ### Function: PrepareModifyBitsProcUnitVariable
#
# **Description:** Description: Purpose: Modify the prepared request by replacing a bit sequence from a variable in the proc unit. Example: *_ApiPrepareModifyBitsProcUnitVariable(1, 8, 16, true, false) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the variable in the proc unit. |  |  |
# | StartBit | int | uint16 |
# | The start bit position. |  |  |
# | BitLength | int | uint16 |
# | The length of the bit sequence. |  |  |
# | ByteOrderBigEndian | boolean | bool |
# | If true, use big-endian byte order. |  |  |
# | AsSignedValue | boolean | bool |
# | If true, interpret the value as signed. |  |  |
#
#
# ---
#
# ### Function: PrepareModifyFromResponsePart
#
# **Description:** Description: Purpose: Prepare the request to be send from the previously received response. Example: *_ApiPrepareModifyFromResponsePart(2, 4, 1) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | RspPartOffset | int | uint16 |
# | The offset of the response part to use. |  |  |
# | RspPartLength | int | uint16 |
# | The length of the response part to use. |  |  |
# | ReqOffset | int | uint16 |
# | The offset in the request where to insert the response part. |  |  |
#
#
# ---
#
# ### Function: PrepareModifyProcUnitVariable
#
# **Description:** Description: Purpose: Modify the prepared repuest by replacing a byte sequence from a variable in the proc unit. Example: *_ApiPrepareModifyProcUnitVariable(1, 2, 4, true) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | VariableIndex | int | uint8 |
# | The index of the variable in the proc unit. |  |  |
# | Offset | int | uint16 |
# | The offset where to replace the data. |  |  |
# | ByteLength | int | uint8 |
# | The length of the byte sequence to replace. |  |  |
# | ByteOrderBigEndian | boolean | bool |
# | If true, use big-endian byte order. |  |  |
#
#
# ---
#
# ### Function: PrepareModifyWithMask
#
# **Description:** Description: Purpose: Modify the prepared repuest by replacing a masked byte sequence. Example: *_ApiPrepareModifyWithMask(2, [0x01, 0x02], [0xFF, 0x0F]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset where to replace the data. |  |  |  |
# | Data | int[] | uint8 | raw |
# | The data to replace with. |  |  |  |
# | Mask | int[] | uint8 | raw |
# | The mask to apply during replacement. |  |  |  |
#
#
# ---
#
# ### Function: Send
#
# **Description:** Description: Purpose: Send a diagnostic request. If a response is received, store it in the internal buffer and generate a logging message Example: *_ApiSend([0x10, 0x03]) Return Messages: On Success: Logs [Log] if Send is successful On Failure: - Returns [Protocol] error if the transport protocol reported an error. - Returns [Timeout] error if the send didn't execute withing configured timeout. - Returns [SchedNotRunning] error if the scheduler is not running. Parameters: Response timeout: 60000
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
# | The diagnostic request data to be sent. |  |  |  |
#
#
# ---
#
# ### Function: SendCyclicStartNoRespMinDelay
#
# **Description:** Description: Purpose: Sends a diagnostic request cyclically. No response is expected from the other part. Implemented for CAN and Flexray. Not yet implemented for LIN. Example: *_ApiSendCyclicStartNoRespMinDelay([0x10, 0x03], 1000) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
# | The diagnostic request data to be sent cyclically. |  |  |  |
# | MinTime | int | uint32 |  |
# | The minimum time between cyclic sends. |  |  |  |
#
#
# ---
#
# ### Function: SendCyclicStartWithRespMinDelay
#
# **Description:** Description: Purpose: Sends a diagnostic request cyclically. The response can be "get" though the API GetCyclicResponse. Implemented for CAN and Flexray. Not yet implemented for LIN. Example: *_ApiSendCyclicStartWithRespMinDelay([0x10, 0x03], 1000) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
# | The diagnostic request data to be sent cyclically. |  |  |  |
# | MinTime | int | uint32 |  |
# | The minimum time between cyclic sends. |  |  |  |
#
#
# ---
#
# ### Function: SendCyclicStop
#
# **Description:** Description: Purpose: Stops the cyclically sent diagnostic request. Example: *_ApiSendCyclicStop()
#
#
# ---
#
# ### Function: SendPrepared
#
# **Description:** Description: Purpose: Send a diagnostic request. If a response is received, store it in the internal buffer and generate a logging message Example: *_ApiSendPrepared() Return Messages: On Success: Logs [Log] if Send is successful On Failure: - Returns [Protocol] error if the transport protocol reported an error. - Returns [Timeout] error if the send didn't execute withing configured timeout. - Returns [SchedNotRunning] error if the scheduler is not running. Response timeout: 60000
#
#
# ---
#
# ### Function: SetPadding
#
# **Description:** Description: Purpose: Set the padding byte used in the Tx Diagnostic Buffer. Example: *_ApiSetPadding(0x55) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Value | int | uint8 |
# | The byte value to be used for padding in the transmit diagnostic buffer. |  |  |
#
#
# ---
#
# ### Function: SetUserTag
#
# **Description:** Description: The user tag is a u16 value. Set the user tag by changing the bits according to the Mask and Value.
# The user tag is stored for each object and is copied into each message that is generated by this object.
# It is up to the user to define the meaning of the user tag. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Mask | int | uint32 | hex |
# | Value | int | uint32 | hex |
#
#
# ---
#
# ### Function: TestByteSequence
#
# **Description:** Description: Purpose: Test the byte sequence in the diag response. It can also used to check on the positive or negative response without the need to check the data in the response. Example: *_ApiSend("10 01") *_ApiTestByteSequence(0, [0x50, 0x01]) *_ApiSend("22 F1 90") *_ApiTestByteSequence(0, [0x62, 0xF1, 0x90]) Return Messages: On Success: Logs [TestByteSequence] if the response as expected. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset in byte count for the sequence. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceDoesNotExist
#
# **Description:** Description: Purpose: Tests the absence of a byte sequence in response starting from the "StartIndex" byte position. Example: *_ApiTestByteSequenceDoesNotExist(2, 1, [0x01, 0x02]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | StartIndex | int | uint8 |  |
# | The start index for the search. |  |  |  |
# | SearchStep | int | uint8 |  |
# | The step size for the search. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected to be not in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceExist
#
# **Description:** Description: Purpose: Tests the existence of a byte sequence in response starting from the "StartIndex" byte position. Example: *_ApiTestByteSequenceExist(2, 1, [0x01, 0x02]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | StartIndex | int | uint8 |  |
# | The start index for the search. |  |  |  |
# | SearchStep | int | uint8 |  |
# | The step size for the search. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceNotMatching
#
# **Description:** Description: Purpose: Test for a byte sequence in the response that should not match. Example: *_ApiTestByteSequenceNotMatching(2, [0x01, 0x02]) Return Messages: On Success: Logs [TestByteSequenceNotMatching] if the response not matching the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset in byte count for the sequence. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected to not be in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceWithMask
#
# **Description:** Description: Purpose: Test for a byte sequence in the response with a mask. Example: *_ApiTestByteSequenceWithMask(2, [0xFF, 0x0F], [0x01, 0x02]) Return Messages: On Success: Logs [TestByteSequenceWithMask] if the response as expected. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset in byte count for the sequence. |  |  |  |
# | Mask | int[] | uint8 | raw |
# | Mask for the bits to test. Only bits set to true are tested. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceWithMaskDoesNotExist
#
# **Description:** Description: Purpose: Tests the absence of a byte sequence in response starting from the "StartIndex" byte position with a mask. Example: *_ApiTestByteSequenceWithMaskDoesNotExist(2, 1, [0x01, 0x02], [0xFF, 0x0F]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | StartIndex | int | uint8 |  |
# | The start index for the search. |  |  |  |
# | SearchStep | int | uint8 |  |
# | The step size for the search. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected to be not in the response. |  |  |  |
# | Mask | int[] | uint8 | raw |
# | Mask for the bits to test. Only bits set to true are tested. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceWithMaskExist
#
# **Description:** Description: Purpose: Tests the existence of a byte sequence in response starting from the "StartIndex" byte position with a mask. Example: *_ApiTestByteSequenceWithMaskExist(2, 1, [0x01, 0x02], [0xFF, 0x0F]) Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | StartIndex | int | uint8 |  |
# | The start index for the search. |  |  |  |
# | SearchStep | int | uint8 |  |
# | The step size for the search. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected in the response. |  |  |  |
# | Mask | int[] | uint8 | raw |
# | Mask for the bits to test. Only bits set to true are tested. |  |  |  |
#
#
# ---
#
# ### Function: TestByteSequenceWithMaskNotMatching
#
# **Description:** Description: Purpose: Test for a byte sequence in the response that should not match, with a mask. Example: *_ApiTestByteSequenceWithMaskNotMatching(2, [0xFF, 0x0F], [0x01, 0x02]) Return Messages: On Success: Logs [TestByteSequenceWithMaskNotMatching] if the response not matching the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint16 |  |
# | The offset in byte count for the sequence. |  |  |  |
# | Mask | int[] | uint8 | raw |
# | Mask for the bits to test. Only bits set to true are tested. |  |  |  |
# | Data | int[] | uint8 | raw |
# | Raw data that is expected to not be in the response. |  |  |  |
#
#
# ---
#
# ### Function: TestByteValueNoneOf
#
# **Description:** Description: Purpose: Test that a byte in the Diag Response is none of some given list of values. Offset: Byte Position TestValues: Byte Array with needed list of values Example: *_ApiTestByteValueNoneOf(3, [0xCC, 0xDD]) Return Messages: On Success: Logs [TestByteValueNoneOf] if the response matches the expected response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint8 |  |
# | The byte position (0-indexed offset) in the diagnostic response to test. |  |  |  |
# | TestValues | int[] | uint8 | raw |
# | An array of byte values. The test passes if the byte at the specified offset does not match any value in this list. |  |  |  |
#
#
# ---
#
# ### Function: TestByteValueOneOf
#
# **Description:** Description: Purpose: Test that a byte in the Diag Response is one of some given list of values. Offset: Byte Position TestValues: Byte Array with needed list of values Example: *_ApiTestByteValueOneOf(3, [0xAA, 0xBB]) Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Offset | int | uint8 |  |
# | The byte position (0-indexed offset) in the diagnostic response to test. |  |  |  |
# | TestValues | int[] | uint8 | raw |
# | An array of byte values. The test passes if the byte at the specified offset matches any value in this list. |  |  |  |
#
#
# ---
#
# ### Function: TestResponse
#
# **Description:** Description: Purpose: Test if a response is stored. Then verify the response length is in range LengthMin .. LengthMax, inclusive. Example: *_ApiTestResponse(10, 20) Return Messages: On Success: Logs [TestResponse] if the response is as expected. On Failure: - Returns [NoData] error if no response is stored. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | LengthMin | int | uint16 |
# | Minimal valid length of the response. |  |  |
# | LengthMax | int | uint16 |
# | Maximal valid length of the response. |  |  |
#
#
# ---
#
# ### Function: TestResponseNotReceived
#
# **Description:** Description: Purpose: Test if no response is stored. Example: *_ApiTestResponseNotReceived() Return Messages: On Success: Logs [TestResponse] if the response is as expected. On Failure: - Returns [NoData] error if no response is stored. Response timeout: 0
#
#
# ---
#
# ### Function: TestUdsDtcNotPresent
#
# **Description:** Description: Purpose: The function can be used when the user sends 19 02 XX diagnostic request (Report DTC by Status mask) to the ECU and wants to check the absence of a DTC. The response will be the following: [59 02 XX [DTC_1_HighByte DTC_1_MidByte DTC_1_LowByte DTC_1_Status] ... [DTC_n_HighByte DTC_n_MidByte DTC_n_LowByte DTC_n_Status]]. If the DTC is NOT in the response, CASTLE generates 'TestUdsDtcPresence' information message with 0 byte index. If the DTC is in the list, CASTLE generates a 'TestUdsDtcPresence' error message with the byte index of the DTC in the response. Example: *_ApiTestUdsDtcNotPresent(0x123456) Return Messages: On Success: Logs [TestUdsDtcPresence] if the DTC not presenct as expected. On Failure: - Returns [NoData] error if no response is stored. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | DtcId | int | uint32 | hex |
# | The DTC ID to check for absence. |  |  |  |
#
#
# ---
#
# ### Function: TestUdsDtcPresent
#
# **Description:** Description: Purpose: The function can be used when the user sends 19 02 XX diagnostic request (Report DTC by Status mask) to the ECU and wants to check the presence of a DTC. The response will be the following: [59 02 XX [DTC_1_HighByte DTC_1_MidByte DTC_1_LowByte DTC_1_Status] ... [DTC_n_HighByte DTC_n_MidByte DTC_n_LowByte DTC_n_Status]]. If the DTC is in the response, CASTLE generates 'TestUdsDtcPresence' information message with the byte index of the DTC in the response. If the DTC is NOT in the list, CASTLE generates a 'TestUdsDtcPresence' error message with 0 byte index. Example: *_ApiTestUdsDtcPresent(0x123456) Return Messages: On Success: Logs [TestUdsDtcPresence] if the DTC presence as expected. On Failure: - Returns [NoData] error if no response is stored. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | DtcId | int | uint32 | hex |
# | The DTC ID to check for presence. |  |  |  |
#
#
# ---
#
# ### Function: TestUdsDtcStatus
#
# **Description:** Description: Purpose: The function can be used when the user sends 19 02 XX diagnostic request (Report DTC by Status mask) to the ECU and wants to check the status of a DTC. The response will be the following: [59 02 XX [DTC_1_HighByte DTC_1_MidByte DTC_1_LowByte DTC_1_Status] ... [DTC_n_HighByte DTC_n_MidByte DTC_n_LowByte DTC_n_Status]]. If the DTC is in the response AND the expected status matches the masked status byte, CASTLE generates 'TestUdsDtcStatus' information message. If the DTC is in the response AND the expected status does not match the masked status byte, CASTLE generates 'TestUdsDtcStatus' error message. If the DTC is NOT in the list, CASTLE generates a 'TestUdsDtcPresence' error message. Example: *_ApiTestUdsDtcStatus(0x123456, 0xFF, 0x01) Return Messages: On Success: Logs [TestUdsDtcPresence] if the DTC status as expected. On Failure: - Returns [NoData] error if no response is stored. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | DtcId | int | uint32 | hex |
# | The DTC ID to check for status. |  |  |  |
# | Mask | int | uint8 | hex |
# | Only the masked bits will be tested in the status byte. |  |  |  |
# | Status | int | uint8 | hex |
# | The expected status of the DTC. |  |  |  |
#
#
# ---
#
# ### Function: TestUdsDtcsPresentSubsetOf
#
# **Description:** Description: Purpose: The function can be used when the user sends 19 02 XX diagnostic request (Report DTC by Status mask) to the ECU and wants to check the existing DTCs are subset of a predefined list (DtcIdsAllowed). The received response must be the following: [59 02 XX [DTC_1_HighByte DTC_1_MidByte DTC_1_LowByte DTC_1_Status] ... [DTC_n_HighByte DTC_n_MidByte DTC_n_LowByte DTC_n_Status]]. It is not mandatory that the response contains all DTCs exist in the list (DtcIdsAllowed). If any DTC in the response is NOT exist in the list (DtcIdsAllowed), CASTLE generates a 'TestUdsDtcsPresentSubsetOf' error message with all present DTCs and not exist in the list. Example: *_ApiTestUdsDtcsPresentSubsetOf([0x123456, 0xABCDEF]) Return Messages: On Success: Logs [TestUdsDtcsPresentSubsetOf] if the subset dtc list as expected. On Failure: - Returns [NoData] error if no response is stored. - Returns [InvalidResponse] error if the subset is not present in the response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | DtcIdsAllowed | int[] | uint32 | hex |
# | Array of all allowed DTCs (without status mask). |  |  |  |
#
#
# ---
#
# ### Function: TestValueBitSequenceInRange
#
# **Description:** Description: Purpose: Test for a numerical value range, where the number is interpreted as (un)signed value. Example: *_ApiTestValueOutOfRange(true, 2, 2, true, -100, -50, 50, 100) Return Messages: On Success: Logs [TestValueInRange] if the response matches the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | StartBit | int | uint16 |
# | start bit index in the data buffer the left |  |  |
# | BitLength | int | uint16 |
# | number of bits |  |  |
# | IsLsbFirst | boolean | bool |
# | true if the start bit is the least significant |  |  |
# | AsSignedValue | boolean | bool |
# | signed value or unsigned |  |  |
# | LimitErrorMin | long | int64 |
# | Minimum value that is not yet an error |  |  |
# | LimitWarnMin | long | int64 |
# | Minimum value that is not yet a warning |  |  |
# | LimitWarnMax | long | int64 |
# | Maximum value that is not yet a warning |  |  |
# | LimitErrorMax | long | int64 |
# | Maximum value that is not yet an error |  |  |
#
#
# ---
#
# ### Function: TestValueBitsInRange
#
# **Description:** Description: Purpose: Test for a numerical value range, where the number is interpreted as (un)signed value. The limits values are inclusive, so if the value is equal to a boundary it counts as in range. The startbit is in case of big endian (motorola) the most significant bit, in case of little endian (intel) it is the least significant bit. 1. Startbit 7, Length 8, Big Endian 2. Startbit 8, Length 8, Little Endian 3. Startbit 31, Length 9, Big Endian 4. Startbit 48, Length 9, Little Endian If complete bytes shall be tested, see TestValueInRange. Example: *_ApiTestValueBitsInRange(true, 2, 2, true, -100, -50, 50, 100) Return Messages: On Success: Logs [TestValueInRange] if the response matches the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | StartBit | int | uint16 |
# | Big or Little Endian |  |  |
# | BitLength | int | uint16 |
# | ByteOrderBigEndian | boolean | bool |
# | AsSignedValue | boolean | bool |
# | LimitErrorMin | long | int64 |
# | Minimum value that is not yet an error |  |  |
# | LimitWarnMin | long | int64 |
# | Minimum value that is not yet a warning |  |  |
# | LimitWarnMax | long | int64 |
# | Maximum value that is not yet a warning |  |  |
# | LimitErrorMax | long | int64 |
# | Maximum value that is not yet an error |  |  |
#
#
# ---
#
# ### Function: TestValueBitsOutOfRange
#
# **Description:** Description: Purpose: Test for a numerical value range, where the number is interpreted as (un)signed value. The limits values are exclusive, so if the value is equal to a boundary it counts as out of range. The startbit is in case of big endian (motorola) the most significant bit, in case of little endian (intel) it is the least significant bit. 1: Startbit 7, Length 8, Big Endian 2: Startbit 8, Length 8, Little Endian 3: Startbit 31, Length 9, Big Endian 4: Startbit 48, Length 9, Little Endian Example: *_ApiTestValueBitsOutOfRange(true, 2, 2, true	-100, -50, 50, 100) Return Messages: On Success: Logs [TestValueOutOfRange] if the response matches the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | StartBit | int | uint16 |
# | Big or Little Endian |  |  |
# | BitLength | int | uint16 |
# | ByteOrderBigEndian | boolean | bool |
# | AsSignedValue | boolean | bool |
# | LimitWarnMin | long | int64 |
# | Minimum value that is already a warning |  |  |
# | LimitErrorMin | long | int64 |
# | Minimum value that is already an error |  |  |
# | LimitErrorMax | long | int64 |
# | Maximum value that is already an error |  |  |
# | LimitWarnMax | long | int64 |
# | Maximum value that is already a warning |  |  |
#
#
# ---
#
# ### Function: TestValueInRange
#
# **Description:** Description: Purpose: Test for a numerical value range, where the number is interpreted as signed value or either 8, 16, 24 or 32 bit. The byte order can be configured. Example: *_ApiTestValueInRange(true, 2, 2, true, -100, -50, 50, 100) Return Messages: On Success: Logs [TestValueInRange] if the response matches the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | ByteOrderBigEndian | boolean | bool |
# | Big or Little Endian. |  |  |
# | Offset | int | uint16 |
# | Offset in byte count. |  |  |
# | BytesCount | int | uint8 |
# | The number of bytes to include in the value. Valid values are 1 .. 4. |  |  |
# | AsSignedValue | boolean | bool |
# | If true, interpret the value as signed. |  |  |
# | LimitErrorMin | long | int64 |
# | Minimum value that is not yet an error. |  |  |
# | LimitWarnMin | long | int64 |
# | Minimum value that is not yet a warning. |  |  |
# | LimitWarnMax | long | int64 |
# | Maximum value that is not yet a warning. |  |  |
# | LimitErrorMax | long | int64 |
# | Maximum value that is not yet an error. |  |  |
#
#
# ---
#
# ### Function: TestValueOutOfRange
#
# **Description:** Description: Purpose: Test for a numerical value range, where the number is interpreted as (un)signed value. The limits values are exclusive, so if the value is equal to a boundary it counts as out of range. Example: *_ApiTestValueOutOfRange(true, 2, 2, true, -100, -50, 50, 100) Return Messages: On Success: Logs [TestValueInRange] if the response matches the expected response. On Failure: - Returns [NoData] error if no response is stored. - Returns [IndexOutOfBounds] error if the expected response length more than the actuall response. Parameters: Response timeout: 0
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | ByteOrderBigEndian | boolean | bool |
# | Big or Little Endian |  |  |
# | Offset | int | uint16 |
# | in byte count |  |  |
# | BytesCount | int | uint8 |
# | The number of bytes to include in the value. Valid values are 1 .. 4. |  |  |
# | AsSignedValue | boolean | bool |
# | LimitWarnMin | long | int64 |
# | Minimum value that is already a warning |  |  |
# | LimitErrorMin | long | int64 |
# | Minimum value that is already an error |  |  |
# | LimitErrorMax | long | int64 |
# | Maximum value that is already an error |  |  |
# | LimitWarnMax | long | int64 |
# | Maximum value that is already a warning |  |  |
#
#
# ---
#
# ### Message: ByteValueTestNoneOf
#
# **Description:** Description: Obtained byte value is none from the given list Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | ObtainedByteValue | int | uint8 | hex |
# | ExpectedList | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: ByteValueTestOneOf
#
# **Description:** Description: Obtained byte value is one from the given list Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | ObtainedByteValue | int | uint8 | hex |
# | ExpectedList | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: GeneralMessage
#
# **Description:** Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | utf8 |
#
#
# ---
#
# ### Message: GetCyclicResponse
#
# **Description:** Description: Returns the latest response received from the cyclic diag request. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: IndexOutOfBounds
#
# **Description:** Description: A given offset or calculated offset value exceeds the length of the received response. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Offset | int | uint16 |
# | Length | int | uint16 |
#
#
# ---
#
# ### Message: InvalidMasklength
#
# **Description:** Description: The used mask length doesn't match the data length.
#
#
# ---
#
# ### Message: InvalidResponse
#
# **Description:** Description: The current response is not valid to apply this API Used only with response 59 02 xx .....
#
#
# ---
#
# ### Message: InvalidSearchStep
#
# **Description:** Description: The used search step is invalid.
#
#
# ---
#
# ### Message: Log
#
# **Description:** Description: Received response Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: LogAdditionBytesWithMask
#
# **Description:** Description: Log response addition bytes with offset "Index" Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Index | int | uint16 |  |
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
# | Mask | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: LogAdditionBytesWithShortData
#
# **Description:** Description: Log response addition bytes with offset "Index" Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Index | int | uint16 |  |
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
# | ShortData | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: MsgTooLong
#
# **Description:** Description: The received response is too large for the internal buffer.
#
#
# ---
#
# ### Message: NoData
#
# **Description:** Description: Data is not yet received.
#
#
# ---
#
# ### Message: PreparedRequest
#
# **Description:** Description: The data send out. This is generated by SendPreparedRequest Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: Protocol
#
# **Description:** Description: Transport layer error. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Code | int | int32 |
#
#
# ---
#
# ### Message: ResponsePending
#
# **Description:** Description: DUT returned response pending.
#
#
# ---
#
# ### Message: ResponseTooShort
#
# **Description:** Description: The received response is too Short. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: SchedNotRunning
#
# **Description:** Description: LinMaster scheduling is not running.
#
#
# ---
#
# ### Message: TestByteSequence
#
# **Description:** Description: Test of a byte sequence Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | OffsetInResponse | int | uint16 |  |
# | FailIdxInData | int | uint16 |  |
# | ExpectedData | int[] | uint8 | raw |
# | ShortData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestByteSequenceDoesNotExist
#
# **Description:** Description: Tests the absence of a byte sequnece in diag response. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestByteSequenceExist
#
# **Description:** Description: Tests the existance of a byte sequnece in diag response. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestByteSequenceNotMatching
#
# **Description:** Description: Test of a byte sequence Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | OffsetInResponse | int | uint16 |  |
# | FailIdxInData | int | uint16 |  |
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestByteSequenceWithMask
#
# **Description:** Description: Patterntest schlug fehl Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | OffsetInResponse | int | uint16 |  |
# | FailIdxInData | int | uint16 |  |
# | Mask | int[] | uint8 | raw |
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestByteSequenceWithMaskNotMatching
#
# **Description:** Description: Patterntest schlug fehl Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | OffsetInResponse | int | uint16 |  |
# | FailIdxInData | int | uint16 |  |
# | Mask | int[] | uint8 | raw |
# | ExpectedData | int[] | uint8 | raw |
# | Data | int[] | uint8 | raw |
#
#
# ---
#
# ### Message: TestResponse
#
# **Description:** Description: Test if response is received and its length. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | ResponseReceived | boolean | bool |
# | Length | int | uint16 |
#
#
# ---
#
# ### Message: TestUdsDtcPresence
#
# **Description:** Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Dtc | int | uint32 | hex |
# | Idx | int | uint8 |  |
#
#
# ---
#
# ### Message: TestUdsDtcStatus
#
# **Description:** Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | Dtc | int | uint32 | hex |
# | Idx | int | uint8 |  |
# | ExpectedStatus | int | uint8 | hex |
# | Status | int | uint8 | hex |
# | Mask | int | uint8 | hex |
#
#
# ---
#
# ### Message: TestUdsDtcsPresentSubsetOf
#
# **Description:** Description: List all DTCs which are not allowed to be present Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType | Format |
# |---|---|---|---|
# | NotAllowedDtcs | int[] | uint32 | hex |
#
#
# ---
#
# ### Message: TestValueBitsInRange
#
# **Description:** Description: Result of the range test Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | StartBit | int | uint16 |
# | BitLength | int | uint16 |
# | ByteOrderBigEndian | boolean | bool |
# | Big or Little Endian |  |  |
# | AsSignedValue | boolean | bool |
# | LimitErrorMin | long | int64 |
# | LimitWarnMin | long | int64 |
# | Value | long | int64 |
# | LimitWarnMax | long | int64 |
# | LimitErrorMax | long | int64 |
#
#
# ---
#
# ### Message: TestValueBitsOutOfRange
#
# **Description:** Description: Result of the range test Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | StartBit | int | uint16 |
# | BitLength | int | uint16 |
# | ByteOrderBigEndian | boolean | bool |
# | Big or Little Endian |  |  |
# | AsSignedValue | boolean | bool |
# | LimitWarnMin | long | int64 |
# | LimitErrorMin | long | int64 |
# | Value | long | int64 |
# | LimitErrorMax | long | int64 |
# | LimitWarnMax | long | int64 |
#
#
# ---
#
# ### Message: TestValueInRange
#
# **Description:** Description: Result of the in range test Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Offset | int | uint16 |
# | LimitErrorMin | long | int64 |
# | LimitWarnMin | long | int64 |
# | Value | long | int64 |
# | LimitWarnMax | long | int64 |
# | LimitErrorMax | long | int64 |
#
#
# ---
#
# ### Message: TestValueOutOfRange
#
# **Description:** Description: Result of the out of range test Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Offset | int | uint16 |
# | LimitWarnMin | long | int64 |
# | LimitErrorMin | long | int64 |
# | Value | long | int64 |
# | LimitErrorMax | long | int64 |
# | LimitWarnMax | long | int64 |
#
#
# ---
#
# ### Message: Timeout
#
# **Description:** Description: Timeout while waiting for the DUT.
#
#
# ---
#
# ### Message: TpInternalError
#
# **Description:** Description: A error condition in the TP implementation occurred. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Code | int | int32 |
#
#
# ---
#
# ### Message: TpUnknownError
#
# **Description:** Description: A error condition in the TP implementation occurred. Parameters:
#
# **Parameters:**
#
# | Name | Type | EncodedType |
# |---|---|---|
# | Code | int | int32 |
#
#
# ---
#
# ### Message: TxConf
#
# **Description:** Description: Tx Confirmation
#
#
# ---
#
# ### Message: UnexpectedReceive
#
# **Description:** Description: Received a frame from the DUT when it was not expected.
#
#
# ---
# ✅ Original doc metadata:
# {'source': 'FlexrayDiag.md'}

# %%
from langchain.prompts import ChatPromptTemplate

# Multi Query: Different Perspectives
template = """You are an AI language model assistant. Your task is to generate only one more 
different version of the given user question to retrieve relevant documents from a vector 
database. By generating multiple perspectives on the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search. 
Provide these alternative questions separated by newlines. Original question: {question}"""
prompt_perspectives = ChatPromptTemplate.from_template(template)

from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

generate_queries = (
    prompt_perspectives 
    | ChatOpenAI(temperature=0, model="gpt-4.1") 
    | StrOutputParser() 
    | (lambda x: x.split("\n"))
)

# %%
from langchain.load import dumps, loads
from langchain_core.runnables import RunnableLambda

def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    unique_docs = list(set(flattened_docs))
    return [loads(doc) for doc in unique_docs]

def add_original_query(inputs: dict):
    """Add original question back to generated queries"""
    question = inputs["question"]
    queries = generate_queries.invoke({"question": question})
    if question not in queries:
        queries = [question] + queries
    return {"queries": queries}

def search_with_queries(inputs: dict):
    all_results = []
    for q in inputs["queries"]:
        results = retriever_api.invoke(q)  # summaries with metadata
        print(f"Query: {q} -> {len(results)} results")
        print(f"Results: {[doc.metadata.get('source', 'unknown') for doc in results]}")
        all_results.append(results)
    return all_results

def swap_for_original(docs):
    """Replace summary docs with their original full docs from docstore"""
    originals = []
    for d in docs:
        doc_id = d.metadata.get("doc_id")
        if doc_id:
            orig = retriever.docstore.mget([doc_id])[0]
            if orig:  # fallback if not found
                originals.append(orig)
            else:
                originals.append(d)  # keep summary if original missing
        else:
            originals.append(d)  # keep summary if no id
    return originals

# Wrap with RunnableLambda
retrieval_chain = (
    RunnableLambda(add_original_query)
    | RunnableLambda(search_with_queries)
    | RunnableLambda(get_unique_union)
    | RunnableLambda(swap_for_original)  # 🔥 convert to original docs here
)

# %%
from operator import itemgetter
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough

# RAG
template = """Answer the following question based on this context:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

llm = ChatOpenAI(temperature=0, model="gpt-4.1")

def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

final_rag_chain = (
    {
        "context": retrieval_chain | RunnableLambda(format_docs),
        "question": itemgetter("question"),
    }
    | prompt
    | llm
    | StrOutputParser()
)

final_rag_chain.invoke({"question":"how to start sending Lin diags? explain step by step."})
# Out:
# Query: how to start sending Lin diags? explain step by step. -> 1 results
# Results: ['LinDiag.md']
# Query: What are the step-by-step instructions for initiating LIN diagnostics communication? -> 1 results
# Results: ['LinDiag.md']
# Query:  -> 1 results
# Results: ['ComPcEthernetPdus.md']
# Query: Can you provide a detailed guide on how to begin sending LIN diagnostic messages? -> 1 results
# Results: ['LinDiag.md']
# 'To **start sending LIN diagnostics (diags)**, you need to configure the diagnostic environment and send your first diagnostic request. Here’s a step-by-step guide based on the provided API/context:\n\n---\n\n## **Step 1: Configure the Diagnostic Environment**\n\n### 1. **Set the Default NAD (Node Address)**\nLIN diagnostics require a NAD (Node Address) to address the correct slave node.\n\n```plaintext\n*_ApiConfigureDefault_NAD(0x7E)\n```\n- Replace `0x7E` with the NAD of your target LIN slave.\n\n---\n\n### 2. **Enable the Diagnostic Module (Transport Protocol)**\nEnable the Transport Protocol (TP) layer for diagnostics.\n\n```plaintext\n*_ApiConfigureDiag(true)\n```\n\n---\n\n### 3. **(Optional) Set Default Timeouts**\nConfigure the default timeouts for diagnostic requests and pending responses.\n\n```plaintext\n*_ApiConfigureDefaultTimeout(1000, 5000)\n```\n- `1000` ms for normal response timeout (P2server)\n- `5000` ms for pending response timeout (P2*server)\n\n---\n\n### 4. **(Optional) Set Slave Response Timeout**\nSet the time the LIN slave has to respond after receiving a request.\n\n```plaintext\n*_ApiSetSlaveResponseTimeout(60)\n```\n- `60` ms is just an example; adjust as needed.\n\n---\n\n## **Step 2: Prepare and Send a Diagnostic Request**\n\n### 1. **Prepare the Request Data**\nFor example, to request a session change:\n\n```plaintext\n*_ApiPrepare([0x10, 0x03])\n```\n- `[0x10, 0x03]` is a typical "Diagnostic Session Control" request.\n\n---\n\n### 2. **Send the Prepared Request**\nSend the request to the LIN slave:\n\n```plaintext\n*_ApiSendPrepared()\n```\n- This will transmit the prepared request and wait for a response.\n\n---\n\n### 3. **(Alternative) Send Directly Without Prepare**\nYou can also send a request directly:\n\n```plaintext\n*_ApiSend([0x10, 0x03])\n```\n\n---\n\n## **Step 3: Handle the Response**\n\n- The response will be stored in the internal buffer.\n- You can use test functions (e.g., *_ApiTestByteSequence(0, [0x50, 0x03])) to check the response.\n- On success, a `[Log]` message is generated.\n\n---\n\n## **Summary Table**\n\n| Step | Function | Example |\n|------|----------|---------|\n| 1 | Configure NAD | *_ApiConfigureDefault_NAD(0x7E) |\n| 2 | Enable Diag Module | *_ApiConfigureDiag(true) |\n| 3 | (Optional) Set Timeouts | *_ApiConfigureDefaultTimeout(1000, 5000) |\n| 4 | (Optional) Set Slave Timeout | *_ApiSetSlaveResponseTimeout(60) |\n| 5 | Prepare Request | *_ApiPrepare([0x10, 0x03]) |\n| 6 | Send Request | *_ApiSendPrepared() or *_ApiSend([0x10, 0x03]) |\n\n---\n\n## **Notes**\n- Make sure the LIN master scheduling is running; otherwise, you may get a `[SchedNotRunning]` error.\n- Adjust NAD, timeouts, and request data as per your LIN slave and diagnostic use case.\n- For advanced scenarios, you can configure retries, padding, and other options as needed.\n\n---\n\n**In summary:**  \n1. Set the NAD,  \n2. Enable diagnostics,  \n3. (Optionally) configure timeouts,  \n4. Prepare and send your diagnostic request,  \n5. Check the response.\n\nYou are now ready to start sending LIN diagnostic requests!'

# %%
# Pipeline: wiki -> api -> synthesize
# Run this in the same notebook/session where you already have:
# - vectorstore (Chroma)
# - retriever (MultiVectorRetriever with docstore)
# - generate_queries (the query rewriter runnable)
# - ChatOpenAI, StrOutputParser, ChatPromptTemplate imported

from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain.load import dumps, loads
from langchain_core.runnables import RunnableLambda

# Create filtered retrievers (re-use your vectorstore variable)
# Adjust k as you like (docs returned per generated query)
retriever_wiki = vectorstore.as_retriever(search_kwargs={"k": 5, "filter": {"source_type": "api_summary"}})
retriever_api  = vectorstore.as_retriever(search_kwargs={"k": 3, "filter": {"source_type": "wiki_summary"}})

# LLM + prompt
llm = ChatOpenAI(temperature=0, model="gpt-4o-mini")   # use gpt-4.1 or change to preferred model
qa_prompt = ChatPromptTemplate.from_template(
    "Answer the following question based on this context:\n\n{context}\n\nQuestion: {question}"
)

# Helper: run multi-query retrieval using the generate_queries runnable
def multi_query_retrieve(question: str, retriever_obj, doc_store, max_queries=None):
    """
    Run the generate_queries runnable, run the retriever for each generated query,
    dedupe results, then fetch original docs from doc_store (using doc_id).
    Returns a list of original Documents (not summaries).
    """
    # 1) get generated queries (includes original)
    queries = generate_queries.invoke({"question": question})
    if question not in queries:
        queries = [question] + queries
    if max_queries:
        queries = queries[:max_queries]

    # 2) run retriever for each query (retriever_obj is vectorstore.as_retriever(...))
    all_results = []
    for q in queries:
        results = retriever_obj.invoke(q)  # returns summary Documents
        print(f"Query: {q} -> {len(results)} results")
        print(f"Results: {[doc.metadata.get('source','unknown') for doc in results]}")
        all_results.extend(results)

    # 3) dedupe preserving order (by serialized doc)
    seen = set()
    unique_summaries = []
    for s in all_results:
        key = dumps(s)
        if key not in seen:
            seen.add(key)
            unique_summaries.append(s)

    # 4) map summaries -> original docs using doc_id via doc_store.mget
    doc_ids = []
    for s in unique_summaries:
        doc_id = s.metadata.get("doc_id") or s.metadata.get("doc_id".upper()) or s.metadata.get("docid")
        if doc_id:
            doc_ids.append(doc_id)

    # preserve order and dedupe doc_ids
    seen_ids = set()
    unique_ids = []
    for i in doc_ids:
        if i not in seen_ids:
            seen_ids.add(i)
            unique_ids.append(i)

    originals = []
    if unique_ids:
        originals = doc_store.mget(unique_ids)  # returns list of Documents (same order)
        # some docstores return None for missing ids; filter
        originals = [d for d in originals if d is not None]

    # If docstore lookup returned none or empty, fallback to using the summaries themselves
    if not originals:
        # convert summary -> Document-like object (keeping page_content & metadata)
        originals = unique_summaries

    return originals


# Helper: format documents with optional truncation and include source header
def format_docs_with_source(docs, max_docs=3, max_chars=3000):
    """
    Return a single string that concatenates up to max_docs documents.
    Each doc is truncated to max_chars characters to avoid blowing up the prompt.
    """
    out = []
    for d in docs[:max_docs]:
        src = d.metadata.get("source", d.metadata.get("doc_id", "unknown"))
        text = d.page_content or ""
        if len(text) > max_chars:
            text = text[:max_chars] + "\n\n...[truncated]..."
        out.append(f"Source: {src}\n{text}")
    return "\n\n".join(out)


# Helper: ask the LLM to answer from docs (safe truncation applied)
def answer_from_docs(question: str, docs, max_docs=3, max_chars=3000):
    context = format_docs_with_source(docs, max_docs=max_docs, max_chars=max_chars)
    # run the QA prompt -> LLM -> string
    return (qa_prompt | llm | StrOutputParser()).invoke({"context": context, "question": question})


# Orchestration: wiki -> api -> synthesize
def wiki_then_api_pipeline(question: str,
                           doc_store = retriever.docstore,   # the MultiVectorRetriever.docstore you created earlier
                           wiki_retr = retriever_wiki,
                           api_retr  = retriever_api,
                           wiki_max_queries=3,
                           api_max_queries=2,
                           wiki_max_docs=3,
                           api_max_docs=3,
                           wiki_max_chars=100000,
                           api_max_chars=100000):
    """
    1) multi-query search in wiki_retr
    2) produce wiki_answer
    3) build combined query = original + wiki_answer
    4) multi-query search in api_retr with combined query
    5) produce api_answer
    6) synthesize final answer combining wiki+api answers
    """

    # Step A: wiki retrieval
    wiki_originals = multi_query_retrieve(question, wiki_retr, doc_store, max_queries=wiki_max_queries)

    # Step B: wiki answer
    wiki_answer = answer_from_docs(question, wiki_originals, max_docs=wiki_max_docs, max_chars=wiki_max_chars)

    # Step C: build combined query for API stage (use wiki_answer as context)
    combined_query = question + "\n\nWiki findings (short):\n" + wiki_answer

    # Step D: API retrieval using combined query
    api_originals = multi_query_retrieve(combined_query, api_retr, doc_store, max_queries=api_max_queries)

    # Step E: API answer (use original question as the question for consistency)
    api_answer = answer_from_docs(question, api_originals, max_docs=api_max_docs, max_chars=api_max_chars)

    # Step F: Final synthesis (mix wiki_answer + api_answer + original)
    final_context = (
        "WIKI ANSWER:\n" + wiki_answer.strip() + "\n\n"
        "API ANSWER:\n" + api_answer.strip() + "\n\n"
        "Original question:\n" + question
    )

    final_answer = (qa_prompt | llm | StrOutputParser()).invoke({"context": final_context, "question": question})

    return {
        "wiki_answer": wiki_answer,
        "api_answer": api_answer,
        "final_answer": final_answer,
        "wiki_docs": wiki_originals,
        "api_docs": api_originals,
    }


# Example usage:
res = wiki_then_api_pipeline("how to use castle installer?")
print("\n\n=== FINAL SYNTHESIZED ANSWER ===\n")
print(res["final_answer"])
# Out:
# Query: how to initialize flexray diag? explain step by step. -> 5 results
# Results: ['general-topics_flexray_flexray-diag.txt', 'general-topics_flexray_flexrayonoscilloscope.txt', 'test-scripting_hardware-apis_networking-flexray_best-practices_enablecrcsqcforflexray.txt', 'tools_third-party-tools_adtf_extractasciifromdatusingadtf.txt', 'test-scripting_hardware-apis_networking-xcp_configurediagandxcptoworkonthesamemessagesviadynamiccom.txt']
# Query: What are the step-by-step procedures to set up FlexRay diagnostics? -> 5 results
# Results: ['general-topics_flexray_flexray-diag.txt', 'general-topics_flexray_flexrayonoscilloscope.txt', 'test-scripting_hardware-apis_networking-flexray_best-practices_enablecrcsqcforflexray.txt', 'tools_third-party-tools_adtf_extractasciifromdatusingadtf.txt', 'test-scripting_hardware-apis_networking-xcp_configurediagandxcptoworkonthesamemessagesviadynamiccom.txt']
# Query: how to initialize flexray diag? explain step by step.
#
# Wiki findings (short):
# To initialize FlexRay diagnostics (FlexRay Diag), follow these step-by-step instructions:
#
# 1. **Initialize FlexRay Driver**:
#    - Start by initializing the FlexRay driver. This is a crucial step as it sets up the necessary communication interface for the FlexRay protocol.
#
# 2. **Trigger Startup Cluster**:
#    - After the driver is initialized, trigger the startup of the FlexRay cluster. This action prepares the cluster for communication and ensures that all nodes are ready to participate in the FlexRay network.
#
# 3. **Enable RX Processing**:
#    - Next, enable the receive (RX) processing. This step allows the system to start receiving data frames from the FlexRay bus.
#
# 4. **Start Sending Frames**:
#    - Finally, initiate the process of sending frames. This step involves transmitting data over the FlexRay network, allowing for communication between the nodes.
#
# By following these steps, you will successfully initialize the FlexRay diagnostics system. -> 3 results
# Results: ['FlexrayDriver.md', 'FlexrayDiag.md', '_ComFrameStaticFlexrayRxTx.md']
# Query: What are the detailed steps to set up FlexRay diagnostics from scratch? -> 3 results
# Results: ['FlexrayDiag.md', 'FlexrayDriver.md', 'FlexrayXcp.md']
#
#
# === FINAL SYNTHESIZED ANSWER ===
#
# To initialize the FlexRay diagnostics (FlexRay Diag), follow these step-by-step instructions:
#
# ### Step 1: Initialize FlexRay Driver
# - Start by initializing the FlexRay driver. This sets up the necessary communication interface for the FlexRay protocol.
#
# ### Step 2: Trigger Startup Cluster
# - After the driver is initialized, trigger the startup of the FlexRay cluster. This prepares the cluster for communication and ensures that all nodes are ready to participate in the FlexRay network.
#
# ### Step 3: Enable RX Processing
# - Next, enable the receive (RX) processing. This allows the system to start receiving data frames from the FlexRay bus.
#
# ### Step 4: Start Sending Frames
# - Finally, initiate the process of sending frames. This involves transmitting data over the FlexRay network, allowing for communication between the nodes.
#
# ### Additional Steps for API Initialization
# If you are using an API for initialization, follow these additional steps:
#
# 1. **Call the Init Function**: Use the `*_ApiInit()` function to initialize the FlexRay hardware and status variables.
#    ```c
#    *_ApiInit();
#    ```
#
# 2. **Configure Diagnostic Settings**: Enable or disable the Transport Protocol (TP) layer for diagnostics using the `*_ApiConfigureDiag(true)` function.
#    ```c
#    *_ApiConfigureDiag(true);
#    ```
#
# 3. **Set Default Timeout**: Configure the default timeout for all send actions using the `*_ApiConfigureDefaultTimeout(1000, 5000)` function.
#    ```c
#    *_ApiConfigureDefaultTimeout(1000, 5000);
#    ```
#
# 4. **Prepare Diagnostic Requests**: Prepare the request using the `*_ApiPrepare([0x10, 0x03])` function.
#    ```c
#    *_ApiPrepare([0x10, 0x03]);
#    ```
#
# 5. **Send the Prepared Request**: Use the `*_ApiSendPrepared()` function to send the prepared diagnostic request.
#    ```c
#    *_ApiSendPrepared();
#    ```
#
# 6. **Get Cyclic Responses**: If expecting cyclic responses, use the `*_ApiGetCyclicResponse()` function to retrieve the latest response.
#    ```c
#    *_ApiGetCyclicResponse();
#    ```
#
# 7. **Monitor for Errors**: Throughout the process, monitor for any error messages or unexpected responses using functions like `*_ApiTestResponse()`.
#
# By following these steps, you will successfully initialize the FlexRay diagnostics system and prepare it for communication. Adjust parameters as needed based on your specific application requirements.
